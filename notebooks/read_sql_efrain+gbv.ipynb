# %%
import sqlite3 as sql
import pandas as pd
from datetime import timedelta
import missingno as mssgno

# %%
myconn = sql.connect("eplusout.sql")
mycursor = myconn.cursor()

# %%
# Executar comando para extraer nombre de variables
comando = "SELECT ReportDataDictionaryIndex, KeyValue, Name, Units FROM ReportDataDictionary"
variables = pd.read_sql_query(comando,con=myconn)
# variables.set_index('ReportDataDictionaryIndex',inplace=True)
variables
# Out:
#     ReportDataDictionaryIndex                       KeyValue  \
# 0                           7                    Environment
# 1                           9
# 2                          11
# 3                         961                         TZ-D01
# 4                         962                         TZ-D01
# ..                        ...                            ...
# 72                       2093  TZ-D21 IDEAL LOADS AIR SYSTEM
# 73                       2096  TZ-D25 IDEAL LOADS AIR SYSTEM
# 74                       2097  TZ-D25 IDEAL LOADS AIR SYSTEM
# 75                       2100  TZ-D27 IDEAL LOADS AIR SYSTEM
# 76                       2101  TZ-D27 IDEAL LOADS AIR SYSTEM
#
#                                            Name Units
# 0          Site Outdoor Air Drybulb Temperature     C
# 1                          Electricity:Facility     J
# 2                          Electricity:Facility     J
# 3                          Zone Air Temperature     C
# 4                    Zone Air Relative Humidity     %
# ..                                          ...   ...
# 72     Zone Ideal Loads Zone Total Cooling Rate     W
# 73  Zone Ideal Loads Zone Sensible Cooling Rate     W
# 74     Zone Ideal Loads Zone Total Cooling Rate     W
# 75  Zone Ideal Loads Zone Sensible Cooling Rate     W
# 76     Zone Ideal Loads Zone Total Cooling Rate     W
#
# [77 rows x 4 columns]

# %%
# 4. Executar comando para encontrar datos de tiempo
comando = "SELECT tm.TimeIndex, tm.Year, tm.Month, tm.Day, tm.Hour, tm.Minute FROM Time AS tm"
tiempo = pd.read_sql_query(comando,con=myconn)
tiempo = tiempo[tiempo.Year!=0]
tiempo
# Out:
#        TimeIndex  Year  Month  Day  Hour  Minute
# 169          170  2006      1    1     0      10
# 170          171  2006      1    1     0      20
# 171          172  2006      1    1     0      30
# 172          173  2006      1    1     0      40
# 173          174  2006      1    1     0      50
# ...          ...   ...    ...  ...   ...     ...
# 61496      61497  2006     12   31    23      40
# 61497      61498  2006     12   31    23      50
# 61498      61499  2006     12   31    24       0
# 61499      61500  2006     12   31    24       0
# 61500      61501  2006     12   31    24       0
#
# [61332 rows x 6 columns]

# %%
# Executar comando para extraer datos y crear una copia

comando = """SELECT ReportData.TimeIndex, ReportData.ReportDataDictionaryIndex, ReportData.Value
  FROM (ReportData INNER JOIN ReportDataDictionary ON ReportData.ReportDataDictionaryIndex = ReportDataDictionary.ReportDataDictionaryIndex) 
  INNER JOIN Time ON ReportData.TimeIndex = Time.TimeIndex"""
data = pd.read_sql_query(comando,con=myconn)
data
# Out:
#          TimeIndex  ReportDataDictionaryIndex         Value
# 0                1                       2048  3.899745e+03
# 1                1                       2049  7.234953e+03
# 2                1                       2052  1.185320e+03
# 3                1                       2053  1.185320e+03
# 4                1                       2056  1.425413e+03
# ...            ...                        ...           ...
# 2020694      61500                       1762  9.190799e+01
# 2020695      61500                       1801  2.400000e+01
# 2020696      61500                       1802  4.918463e+01
# 2020697      61500                         11  5.860425e+08
# 2020698      61501                          7  2.448331e+01
#
# [2020699 rows x 3 columns]

# %%
datos_variables = pd.merge(data,variables)
datos_variables
# Out:
#          TimeIndex  ReportDataDictionaryIndex        Value  \
# 0                1                       2048  3899.745066
# 1                2                       2048  3689.007241
# 2                3                       2048  3479.387742
# 3                4                       2048  3270.880041
# 4                5                       2048  3063.487429
# ...            ...                        ...          ...
# 2020694      41001                          7    23.444668
# 2020695      46042                          7    23.962141
# 2020696      51251                          7    24.832953
# 2020697      56292                          7    24.505718
# 2020698      61501                          7    24.483311
#
#                               KeyValue  \
# 0        TZ-D01 IDEAL LOADS AIR SYSTEM
# 1        TZ-D01 IDEAL LOADS AIR SYSTEM
# 2        TZ-D01 IDEAL LOADS AIR SYSTEM
# 3        TZ-D01 IDEAL LOADS AIR SYSTEM
# 4        TZ-D01 IDEAL LOADS AIR SYSTEM
# ...                                ...
# 2020694                    Environment
# 2020695                    Environment
# 2020696                    Environment
# 2020697                    Environment
# 2020698                    Environment
#
#                                                 Name Units
# 0        Zone Ideal Loads Zone Sensible Cooling Rate     W
# 1        Zone Ideal Loads Zone Sensible Cooling Rate     W
# 2        Zone Ideal Loads Zone Sensible Cooling Rate     W
# 3        Zone Ideal Loads Zone Sensible Cooling Rate     W
# 4        Zone Ideal Loads Zone Sensible Cooling Rate     W
# ...                                              ...   ...
# 2020694         Site Outdoor Air Drybulb Temperature     C
# 2020695         Site Outdoor Air Drybulb Temperature     C
# 2020696         Site Outdoor Air Drybulb Temperature     C
# 2020697         Site Outdoor Air Drybulb Temperature     C
# 2020698         Site Outdoor Air Drybulb Temperature     C
#
# [2020699 rows x 6 columns]

# %%
datos_variables_tiempo = pd.merge(datos_variables,tiempo)
df = datos_variables_tiempo.copy()
df['fecha'] = pd.to_datetime(df[['Year','Month','Day']])
# agrega un d'ia cuando la hora es 24
df.loc[df.Hour==24,'fecha'] += pd.Timedelta('1D')
# cambia la hora de 24 a 0 
df.loc[df.Hour==24,'Hour'] = 0
# rehace la fecha usando el tiempo
df['fecha'] = pd.to_datetime(df[['Year','Month','Day','Hour','Minute']])
# df['nombre_variable'] = df.KeyValue + ':' + df.Name 
df['nombre_variable'] = df.KeyValue + ':' + df.Name + ' (' + df.Units + ')'
# df.set_index(['nombre_variable','fecha'],inplace=True,drop=False)
df  = df.pivot_table(index="fecha", columns="nombre_variable", values="Value")

# %%
df.columns
# Out:
# Index([':DistrictCooling:Facility (J)', ':DistrictHeating:Facility (J)',
#        ':Electricity:Facility (J)',
#        'Environment:Site Outdoor Air Drybulb Temperature (C)',
#        'TZ-D01 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Sensible Cooling Rate (W)',
#        'TZ-D01 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Total Cooling Rate (W)',
#        'TZ-D01:Zone Air Relative Humidity (%)',
#        'TZ-D01:Zone Air Temperature (C)',
#        'TZ-D02 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Sensible Cooling Rate (W)',
#        'TZ-D02 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Total Cooling Rate (W)',
#        'TZ-D02:Zone Air Relative Humidity (%)',
#        'TZ-D02:Zone Air Temperature (C)',
#        'TZ-D03:Zone Air Relative Humidity (%)',
#        'TZ-D03:Zone Air Temperature (C)',
#        'TZ-D06:Zone Air Relative Humidity (%)',
#        'TZ-D06:Zone Air Temperature (C)',
#        'TZ-D07 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Sensible Cooling Rate (W)',
#        'TZ-D07 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Total Cooling Rate (W)',
#        'TZ-D07:Zone Air Relative Humidity (%)',
#        'TZ-D07:Zone Air Temperature (C)',
#        'TZ-D08 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Sensible Cooling Rate (W)',
#        'TZ-D08 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Total Cooling Rate (W)',
#        'TZ-D08:Zone Air Relative Humidity (%)',
#        'TZ-D08:Zone Air Temperature (C)',
#        'TZ-D09:Zone Air Relative Humidity (%)',
#        'TZ-D09:Zone Air Temperature (C)',
#        'TZ-D10:Zone Air Relative Humidity (%)',
#        'TZ-D10:Zone Air Temperature (C)',
#        'TZ-D11:Zone Air Relative Humidity (%)',
#        'TZ-D11:Zone Air Temperature (C)',
#        'TZ-D12 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Sensible Cooling Rate (W)',
#        'TZ-D12 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Total Cooling Rate (W)',
#        'TZ-D12:Zone Air Relative Humidity (%)',
#        'TZ-D12:Zone Air Temperature (C)',
#        'TZ-D13 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Sensible Cooling Rate (W)',
#        'TZ-D13 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Total Cooling Rate (W)',
#        'TZ-D13:Zone Air Relative Humidity (%)',
#        'TZ-D13:Zone Air Temperature (C)',
#        'TZ-D14 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Sensible Cooling Rate (W)',
#        'TZ-D14 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Total Cooling Rate (W)',
#        'TZ-D14:Zone Air Relative Humidity (%)',
#        'TZ-D14:Zone Air Temperature (C)',
#        'TZ-D16 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Sensible Cooling Rate (W)',
#        'TZ-D16 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Total Cooling Rate (W)',
#        'TZ-D16:Zone Air Relative Humidity (%)',
#        'TZ-D16:Zone Air Temperature (C)',
#        'TZ-D17 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Sensible Cooling Rate (W)',
#        'TZ-D17 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Total Cooling Rate (W)',
#        'TZ-D17:Zone Air Relative Humidity (%)',
#        'TZ-D17:Zone Air Temperature (C)',
#        'TZ-D18 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Sensible Cooling Rate (W)',
#        'TZ-D18 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Total Cooling Rate (W)',
#        'TZ-D18:Zone Air Relative Humidity (%)',
#        'TZ-D18:Zone Air Temperature (C)',
#        'TZ-D19:Zone Air Relative Humidity (%)',
#        'TZ-D19:Zone Air Temperature (C)',
#        'TZ-D20 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Sensible Cooling Rate (W)',
#        'TZ-D20 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Total Cooling Rate (W)',
#        'TZ-D20:Zone Air Relative Humidity (%)',
#        'TZ-D20:Zone Air Temperature (C)',
#        'TZ-D21 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Sensible Cooling Rate (W)',
#        'TZ-D21 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Total Cooling Rate (W)',
#        'TZ-D21:Zone Air Relative Humidity (%)',
#        'TZ-D21:Zone Air Temperature (C)',
#        'TZ-D23:Zone Air Relative Humidity (%)',
#        'TZ-D23:Zone Air Temperature (C)',
#        'TZ-D25 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Sensible Cooling Rate (W)',
#        'TZ-D25 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Total Cooling Rate (W)',
#        'TZ-D25:Zone Air Relative Humidity (%)',
#        'TZ-D25:Zone Air Temperature (C)',
#        'TZ-D26:Zone Air Relative Humidity (%)',
#        'TZ-D26:Zone Air Temperature (C)',
#        'TZ-D27 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Sensible Cooling Rate (W)',
#        'TZ-D27 IDEAL LOADS AIR SYSTEM:Zone Ideal Loads Zone Total Cooling Rate (W)',
#        'TZ-D27:Zone Air Relative Humidity (%)',
#        'TZ-D27:Zone Air Temperature (C)'],
#       dtype='object', name='nombre_variable')

# %%
df.plot(subplots=True,figsize = (20,200));
