# %%
import pandas as pd
import matplotlib.pyplot as plt
from readeplus_sql import *

# %%
# %load readeplus_sql.py

# %%
df = read_eplusql("../data/clase06.sql",read='all',rename=True)#by default reads everything and rename Ti,To
# df = read_eplusql("../data/clase06.sql",read='all')#by default reads everything and rename Ti,To

# df = read_eplusql("../data/eplusoutTo.sql",read='construction') # reads only construction systems
# df = read_eplusql("../data/eplusoutTo.sql",read='data',rename_ZMAT=True) # reads only data

# %%
df.vars_numbered
# Out:
# [(0, ':Electricity:Facility (J)'),
#  (1, 'To'),
#  (2, 'THERMAL ZONE 1:Zone Air Relative Humidity (%)'),
#  (3, 'THERMAL ZONE 1:Zone Air Temperature (C)'),
#  (4, 'Ti_THERMALZONE1'),
#  (5, 'THERMAL ZONE 2:Zone Air Relative Humidity (%)'),
#  (6, 'THERMAL ZONE 2:Zone Air Temperature (C)'),
#  (7, 'Ti_THERMALZONE2'),
#  (8, 'THERMAL ZONE 3:Zone Air Relative Humidity (%)'),
#  (9, 'THERMAL ZONE 3:Zone Air Temperature (C)'),
#  (10, 'Ti_THERMALZONE3')]

# %%
cs = df.construction_systems
cs
# Out:
# array(['ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 1',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 2',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 3',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 4',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 5',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 6',
#        'ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 7-8', 'EXTERIOR DOOR',
#        'INTERIOR CEILING', 'INTERIOR FLOOR', 'INTERIOR WALL',
#        'INTERIOR DOOR', 'INTERIOR PARTITION',
#        'EXTSLABCARPET 4IN CLIMATEZONE 1-8',
#        'ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 1',
#        'ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 2',
#        'ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 2-5',
#        'ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 3',
#        'ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 4',
#        'ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 7-8',
#        'ASHRAE 189.1-2009 EXTROOF METAL CLIMATEZONE 6', 'INTERIOR WINDOW',
#        'ASHRAE 189.1-2009 EXTWINDOW CLIMATEZONE 1',
#        'ASHRAE 189.1-2009 EXTWINDOW CLIMATEZONE 2',
#        'ASHRAE 189.1-2009 EXTWINDOW CLIMATEZONE 3',
#        'ASHRAE 189.1-2009 EXTWINDOW CLIMATEZONE 4-5',
#        'ASHRAE 189.1-2009 EXTWINDOW CLIMATEZONE 6',
#        'ASHRAE 189.1-2009 EXTWINDOW CLIMATEZONE 7-8'], dtype=object)

# %%
df.get_construction(cs)
# Out:
# Construction system:ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 1
# Total thickness    :0.275 m
# Total layers:[4]
# InsideAbsorpVis:[0.4]
# OutsideAbsorpVis:[0.92]
# OutsideAbsorpSolar:[0.92]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[5]
# <style type="text/css">
# </style>
# <table id="T_c1a8e_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c1a8e_row0_col0" class="data row0 col0" >1IN STUCCO</td>
#       <td id="T_c1a8e_row0_col1" class="data row0 col1" >0.691800</td>
#       <td id="T_c1a8e_row0_col2" class="data row0 col2" >1858.000000</td>
#       <td id="T_c1a8e_row0_col3" class="data row0 col3" >837.000000</td>
#       <td id="T_c1a8e_row0_col4" class="data row0 col4" >0.025300</td>
#     </tr>
#     <tr>
#       <td id="T_c1a8e_row1_col0" class="data row1 col0" >8IN CONCRETE HW</td>
#       <td id="T_c1a8e_row1_col1" class="data row1 col1" >1.729600</td>
#       <td id="T_c1a8e_row1_col2" class="data row1 col2" >2243.000000</td>
#       <td id="T_c1a8e_row1_col3" class="data row1 col3" >837.000000</td>
#       <td id="T_c1a8e_row1_col4" class="data row1 col4" >0.203300</td>
#     </tr>
#     <tr>
#       <td id="T_c1a8e_row2_col0" class="data row2 col0" >WALL INSULATION [31]</td>
#       <td id="T_c1a8e_row2_col1" class="data row2 col1" >0.043200</td>
#       <td id="T_c1a8e_row2_col2" class="data row2 col2" >91.000000</td>
#       <td id="T_c1a8e_row2_col3" class="data row2 col3" >837.000000</td>
#       <td id="T_c1a8e_row2_col4" class="data row2 col4" >0.033700</td>
#     </tr>
#     <tr>
#       <td id="T_c1a8e_row3_col0" class="data row3 col0" >1/2IN GYPSUM</td>
#       <td id="T_c1a8e_row3_col1" class="data row3 col1" >0.160000</td>
#       <td id="T_c1a8e_row3_col2" class="data row3 col2" >784.900000</td>
#       <td id="T_c1a8e_row3_col3" class="data row3 col3" >830.000000</td>
#       <td id="T_c1a8e_row3_col4" class="data row3 col4" >0.012700</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 2
# Total thickness    :0.2865 m
# Total layers:[4]
# InsideAbsorpVis:[0.4]
# OutsideAbsorpVis:[0.92]
# OutsideAbsorpSolar:[0.92]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[5]
# <style type="text/css">
# </style>
# <table id="T_a57cb_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a57cb_row0_col0" class="data row0 col0" >1IN STUCCO</td>
#       <td id="T_a57cb_row0_col1" class="data row0 col1" >0.691800</td>
#       <td id="T_a57cb_row0_col2" class="data row0 col2" >1858.000000</td>
#       <td id="T_a57cb_row0_col3" class="data row0 col3" >837.000000</td>
#       <td id="T_a57cb_row0_col4" class="data row0 col4" >0.025300</td>
#     </tr>
#     <tr>
#       <td id="T_a57cb_row1_col0" class="data row1 col0" >8IN CONCRETE HW</td>
#       <td id="T_a57cb_row1_col1" class="data row1 col1" >1.729600</td>
#       <td id="T_a57cb_row1_col2" class="data row1 col2" >2243.000000</td>
#       <td id="T_a57cb_row1_col3" class="data row1 col3" >837.000000</td>
#       <td id="T_a57cb_row1_col4" class="data row1 col4" >0.203300</td>
#     </tr>
#     <tr>
#       <td id="T_a57cb_row2_col0" class="data row2 col0" >WALL INSULATION [35]</td>
#       <td id="T_a57cb_row2_col1" class="data row2 col1" >0.043200</td>
#       <td id="T_a57cb_row2_col2" class="data row2 col2" >91.000000</td>
#       <td id="T_a57cb_row2_col3" class="data row2 col3" >837.000000</td>
#       <td id="T_a57cb_row2_col4" class="data row2 col4" >0.045200</td>
#     </tr>
#     <tr>
#       <td id="T_a57cb_row3_col0" class="data row3 col0" >1/2IN GYPSUM</td>
#       <td id="T_a57cb_row3_col1" class="data row3 col1" >0.160000</td>
#       <td id="T_a57cb_row3_col2" class="data row3 col2" >784.900000</td>
#       <td id="T_a57cb_row3_col3" class="data row3 col3" >830.000000</td>
#       <td id="T_a57cb_row3_col4" class="data row3 col4" >0.012700</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 3
# Total thickness    :0.2979 m
# Total layers:[4]
# InsideAbsorpVis:[0.4]
# OutsideAbsorpVis:[0.92]
# OutsideAbsorpSolar:[0.92]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[5]
# <style type="text/css">
# </style>
# <table id="T_df681_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_df681_row0_col0" class="data row0 col0" >1IN STUCCO</td>
#       <td id="T_df681_row0_col1" class="data row0 col1" >0.691800</td>
#       <td id="T_df681_row0_col2" class="data row0 col2" >1858.000000</td>
#       <td id="T_df681_row0_col3" class="data row0 col3" >837.000000</td>
#       <td id="T_df681_row0_col4" class="data row0 col4" >0.025300</td>
#     </tr>
#     <tr>
#       <td id="T_df681_row1_col0" class="data row1 col0" >8IN CONCRETE HW</td>
#       <td id="T_df681_row1_col1" class="data row1 col1" >1.729600</td>
#       <td id="T_df681_row1_col2" class="data row1 col2" >2243.000000</td>
#       <td id="T_df681_row1_col3" class="data row1 col3" >837.000000</td>
#       <td id="T_df681_row1_col4" class="data row1 col4" >0.203300</td>
#     </tr>
#     <tr>
#       <td id="T_df681_row2_col0" class="data row2 col0" >WALL INSULATION [36]</td>
#       <td id="T_df681_row2_col1" class="data row2 col1" >0.043200</td>
#       <td id="T_df681_row2_col2" class="data row2 col2" >91.000000</td>
#       <td id="T_df681_row2_col3" class="data row2 col3" >837.000000</td>
#       <td id="T_df681_row2_col4" class="data row2 col4" >0.056600</td>
#     </tr>
#     <tr>
#       <td id="T_df681_row3_col0" class="data row3 col0" >1/2IN GYPSUM</td>
#       <td id="T_df681_row3_col1" class="data row3 col1" >0.160000</td>
#       <td id="T_df681_row3_col2" class="data row3 col2" >784.900000</td>
#       <td id="T_df681_row3_col3" class="data row3 col3" >830.000000</td>
#       <td id="T_df681_row3_col4" class="data row3 col4" >0.012700</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 4
# Total thickness    :0.3094 m
# Total layers:[4]
# InsideAbsorpVis:[0.4]
# OutsideAbsorpVis:[0.92]
# OutsideAbsorpSolar:[0.92]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[5]
# <style type="text/css">
# </style>
# <table id="T_d2dd2_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d2dd2_row0_col0" class="data row0 col0" >1IN STUCCO</td>
#       <td id="T_d2dd2_row0_col1" class="data row0 col1" >0.691800</td>
#       <td id="T_d2dd2_row0_col2" class="data row0 col2" >1858.000000</td>
#       <td id="T_d2dd2_row0_col3" class="data row0 col3" >837.000000</td>
#       <td id="T_d2dd2_row0_col4" class="data row0 col4" >0.025300</td>
#     </tr>
#     <tr>
#       <td id="T_d2dd2_row1_col0" class="data row1 col0" >8IN CONCRETE HW</td>
#       <td id="T_d2dd2_row1_col1" class="data row1 col1" >1.729600</td>
#       <td id="T_d2dd2_row1_col2" class="data row1 col2" >2243.000000</td>
#       <td id="T_d2dd2_row1_col3" class="data row1 col3" >837.000000</td>
#       <td id="T_d2dd2_row1_col4" class="data row1 col4" >0.203300</td>
#     </tr>
#     <tr>
#       <td id="T_d2dd2_row2_col0" class="data row2 col0" >WALL INSULATION [37]</td>
#       <td id="T_d2dd2_row2_col1" class="data row2 col1" >0.043200</td>
#       <td id="T_d2dd2_row2_col2" class="data row2 col2" >91.000000</td>
#       <td id="T_d2dd2_row2_col3" class="data row2 col3" >837.000000</td>
#       <td id="T_d2dd2_row2_col4" class="data row2 col4" >0.068100</td>
#     </tr>
#     <tr>
#       <td id="T_d2dd2_row3_col0" class="data row3 col0" >1/2IN GYPSUM</td>
#       <td id="T_d2dd2_row3_col1" class="data row3 col1" >0.160000</td>
#       <td id="T_d2dd2_row3_col2" class="data row3 col2" >784.900000</td>
#       <td id="T_d2dd2_row3_col3" class="data row3 col3" >830.000000</td>
#       <td id="T_d2dd2_row3_col4" class="data row3 col4" >0.012700</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 5
# Total thickness    :0.3207 m
# Total layers:[4]
# InsideAbsorpVis:[0.4]
# OutsideAbsorpVis:[0.92]
# OutsideAbsorpSolar:[0.92]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[5]
# <style type="text/css">
# </style>
# <table id="T_f6b30_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f6b30_row0_col0" class="data row0 col0" >1IN STUCCO</td>
#       <td id="T_f6b30_row0_col1" class="data row0 col1" >0.691800</td>
#       <td id="T_f6b30_row0_col2" class="data row0 col2" >1858.000000</td>
#       <td id="T_f6b30_row0_col3" class="data row0 col3" >837.000000</td>
#       <td id="T_f6b30_row0_col4" class="data row0 col4" >0.025300</td>
#     </tr>
#     <tr>
#       <td id="T_f6b30_row1_col0" class="data row1 col0" >8IN CONCRETE HW</td>
#       <td id="T_f6b30_row1_col1" class="data row1 col1" >1.729600</td>
#       <td id="T_f6b30_row1_col2" class="data row1 col2" >2243.000000</td>
#       <td id="T_f6b30_row1_col3" class="data row1 col3" >837.000000</td>
#       <td id="T_f6b30_row1_col4" class="data row1 col4" >0.203300</td>
#     </tr>
#     <tr>
#       <td id="T_f6b30_row2_col0" class="data row2 col0" >WALL INSULATION [40]</td>
#       <td id="T_f6b30_row2_col1" class="data row2 col1" >0.043200</td>
#       <td id="T_f6b30_row2_col2" class="data row2 col2" >91.000000</td>
#       <td id="T_f6b30_row2_col3" class="data row2 col3" >837.000000</td>
#       <td id="T_f6b30_row2_col4" class="data row2 col4" >0.079400</td>
#     </tr>
#     <tr>
#       <td id="T_f6b30_row3_col0" class="data row3 col0" >1/2IN GYPSUM</td>
#       <td id="T_f6b30_row3_col1" class="data row3 col1" >0.160000</td>
#       <td id="T_f6b30_row3_col2" class="data row3 col2" >784.900000</td>
#       <td id="T_f6b30_row3_col3" class="data row3 col3" >830.000000</td>
#       <td id="T_f6b30_row3_col4" class="data row3 col4" >0.012700</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 6
# Total thickness    :0.3327 m
# Total layers:[4]
# InsideAbsorpVis:[0.4]
# OutsideAbsorpVis:[0.92]
# OutsideAbsorpSolar:[0.92]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[5]
# <style type="text/css">
# </style>
# <table id="T_8404e_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8404e_row0_col0" class="data row0 col0" >1IN STUCCO</td>
#       <td id="T_8404e_row0_col1" class="data row0 col1" >0.691800</td>
#       <td id="T_8404e_row0_col2" class="data row0 col2" >1858.000000</td>
#       <td id="T_8404e_row0_col3" class="data row0 col3" >837.000000</td>
#       <td id="T_8404e_row0_col4" class="data row0 col4" >0.025300</td>
#     </tr>
#     <tr>
#       <td id="T_8404e_row1_col0" class="data row1 col0" >8IN CONCRETE HW</td>
#       <td id="T_8404e_row1_col1" class="data row1 col1" >1.729600</td>
#       <td id="T_8404e_row1_col2" class="data row1 col2" >2243.000000</td>
#       <td id="T_8404e_row1_col3" class="data row1 col3" >837.000000</td>
#       <td id="T_8404e_row1_col4" class="data row1 col4" >0.203300</td>
#     </tr>
#     <tr>
#       <td id="T_8404e_row2_col0" class="data row2 col0" >WALL INSULATION [42]</td>
#       <td id="T_8404e_row2_col1" class="data row2 col1" >0.043200</td>
#       <td id="T_8404e_row2_col2" class="data row2 col2" >91.000000</td>
#       <td id="T_8404e_row2_col3" class="data row2 col3" >837.000000</td>
#       <td id="T_8404e_row2_col4" class="data row2 col4" >0.091400</td>
#     </tr>
#     <tr>
#       <td id="T_8404e_row3_col0" class="data row3 col0" >1/2IN GYPSUM</td>
#       <td id="T_8404e_row3_col1" class="data row3 col1" >0.160000</td>
#       <td id="T_8404e_row3_col2" class="data row3 col2" >784.900000</td>
#       <td id="T_8404e_row3_col3" class="data row3 col3" >830.000000</td>
#       <td id="T_8404e_row3_col4" class="data row3 col4" >0.012700</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTWALL MASS CLIMATEZONE 7-8
# Total thickness    :0.3517 m
# Total layers:[4]
# InsideAbsorpVis:[0.4]
# OutsideAbsorpVis:[0.92]
# OutsideAbsorpSolar:[0.92]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[5]
# <style type="text/css">
# </style>
# <table id="T_2c101_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2c101_row0_col0" class="data row0 col0" >1IN STUCCO</td>
#       <td id="T_2c101_row0_col1" class="data row0 col1" >0.691800</td>
#       <td id="T_2c101_row0_col2" class="data row0 col2" >1858.000000</td>
#       <td id="T_2c101_row0_col3" class="data row0 col3" >837.000000</td>
#       <td id="T_2c101_row0_col4" class="data row0 col4" >0.025300</td>
#     </tr>
#     <tr>
#       <td id="T_2c101_row1_col0" class="data row1 col0" >8IN CONCRETE HW</td>
#       <td id="T_2c101_row1_col1" class="data row1 col1" >1.729600</td>
#       <td id="T_2c101_row1_col2" class="data row1 col2" >2243.000000</td>
#       <td id="T_2c101_row1_col3" class="data row1 col3" >837.000000</td>
#       <td id="T_2c101_row1_col4" class="data row1 col4" >0.203300</td>
#     </tr>
#     <tr>
#       <td id="T_2c101_row2_col0" class="data row2 col0" >WALL INSULATION [44]</td>
#       <td id="T_2c101_row2_col1" class="data row2 col1" >0.043200</td>
#       <td id="T_2c101_row2_col2" class="data row2 col2" >91.000000</td>
#       <td id="T_2c101_row2_col3" class="data row2 col3" >837.000000</td>
#       <td id="T_2c101_row2_col4" class="data row2 col4" >0.110400</td>
#     </tr>
#     <tr>
#       <td id="T_2c101_row3_col0" class="data row3 col0" >1/2IN GYPSUM</td>
#       <td id="T_2c101_row3_col1" class="data row3 col1" >0.160000</td>
#       <td id="T_2c101_row3_col2" class="data row3 col2" >784.900000</td>
#       <td id="T_2c101_row3_col3" class="data row3 col3" >830.000000</td>
#       <td id="T_2c101_row3_col4" class="data row3 col4" >0.012700</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:EXTERIOR DOOR
# Total thickness    :0.0262 m
# Total layers:[2]
# InsideAbsorpVis:[0.6]
# OutsideAbsorpVis:[0.7]
# OutsideAbsorpSolar:[0.7]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[5]
# <style type="text/css">
# </style>
# <table id="T_7daf4_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7daf4_row0_col0" class="data row0 col0" >F08 METAL SURFACE</td>
#       <td id="T_7daf4_row0_col1" class="data row0 col1" >45.280000</td>
#       <td id="T_7daf4_row0_col2" class="data row0 col2" >7824.000000</td>
#       <td id="T_7daf4_row0_col3" class="data row0 col3" >500.000000</td>
#       <td id="T_7daf4_row0_col4" class="data row0 col4" >0.000800</td>
#     </tr>
#     <tr>
#       <td id="T_7daf4_row1_col0" class="data row1 col0" >I01 25MM INSULATION BOARD</td>
#       <td id="T_7daf4_row1_col1" class="data row1 col1" >0.030000</td>
#       <td id="T_7daf4_row1_col2" class="data row1 col2" >43.000000</td>
#       <td id="T_7daf4_row1_col3" class="data row1 col3" >1210.000000</td>
#       <td id="T_7daf4_row1_col4" class="data row1 col4" >0.025400</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:INTERIOR CEILING
# Total thickness    :0.1207 m
# Total layers:[3]
# InsideAbsorpVis:[0.3]
# OutsideAbsorpVis:[0.5]
# OutsideAbsorpSolar:[0.5]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[3]
# <style type="text/css">
# </style>
# <table id="T_cdb80_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_cdb80_row0_col0" class="data row0 col0" >M11 100MM LIGHTWEIGHT CONCRETE</td>
#       <td id="T_cdb80_row0_col1" class="data row0 col1" >0.530000</td>
#       <td id="T_cdb80_row0_col2" class="data row0 col2" >1280.000000</td>
#       <td id="T_cdb80_row0_col3" class="data row0 col3" >840.000000</td>
#       <td id="T_cdb80_row0_col4" class="data row0 col4" >0.101600</td>
#     </tr>
#     <tr>
#       <td id="T_cdb80_row1_col0" class="data row1 col0" >F05 CEILING AIR SPACE RESISTANCE</td>
#       <td id="T_cdb80_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_cdb80_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_cdb80_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_cdb80_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_cdb80_row2_col0" class="data row2 col0" >F16 ACOUSTIC TILE</td>
#       <td id="T_cdb80_row2_col1" class="data row2 col1" >0.060000</td>
#       <td id="T_cdb80_row2_col2" class="data row2 col2" >368.000000</td>
#       <td id="T_cdb80_row2_col3" class="data row2 col3" >590.000000</td>
#       <td id="T_cdb80_row2_col4" class="data row2 col4" >0.019100</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:INTERIOR FLOOR
# Total thickness    :0.1207 m
# Total layers:[3]
# InsideAbsorpVis:[0.5]
# OutsideAbsorpVis:[0.3]
# OutsideAbsorpSolar:[0.3]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[4]
# <style type="text/css">
# </style>
# <table id="T_49663_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_49663_row0_col0" class="data row0 col0" >F16 ACOUSTIC TILE</td>
#       <td id="T_49663_row0_col1" class="data row0 col1" >0.060000</td>
#       <td id="T_49663_row0_col2" class="data row0 col2" >368.000000</td>
#       <td id="T_49663_row0_col3" class="data row0 col3" >590.000000</td>
#       <td id="T_49663_row0_col4" class="data row0 col4" >0.019100</td>
#     </tr>
#     <tr>
#       <td id="T_49663_row1_col0" class="data row1 col0" >F05 CEILING AIR SPACE RESISTANCE</td>
#       <td id="T_49663_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_49663_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_49663_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_49663_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_49663_row2_col0" class="data row2 col0" >M11 100MM LIGHTWEIGHT CONCRETE</td>
#       <td id="T_49663_row2_col1" class="data row2 col1" >0.530000</td>
#       <td id="T_49663_row2_col2" class="data row2 col2" >1280.000000</td>
#       <td id="T_49663_row2_col3" class="data row2 col3" >840.000000</td>
#       <td id="T_49663_row2_col4" class="data row2 col4" >0.101600</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:INTERIOR WALL
# Total thickness    :0.038 m
# Total layers:[3]
# InsideAbsorpVis:[0.4]
# OutsideAbsorpVis:[0.4]
# OutsideAbsorpSolar:[0.4]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[4]
# <style type="text/css">
# </style>
# <table id="T_0068e_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_0068e_row0_col0" class="data row0 col0" >G01A 19MM GYPSUM BOARD</td>
#       <td id="T_0068e_row0_col1" class="data row0 col1" >0.160000</td>
#       <td id="T_0068e_row0_col2" class="data row0 col2" >800.000000</td>
#       <td id="T_0068e_row0_col3" class="data row0 col3" >1090.000000</td>
#       <td id="T_0068e_row0_col4" class="data row0 col4" >0.019000</td>
#     </tr>
#     <tr>
#       <td id="T_0068e_row1_col0" class="data row1 col0" >F04 WALL AIR SPACE RESISTANCE</td>
#       <td id="T_0068e_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_0068e_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_0068e_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_0068e_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <td id="T_0068e_row2_col0" class="data row2 col0" >G01A 19MM GYPSUM BOARD</td>
#       <td id="T_0068e_row2_col1" class="data row2 col1" >0.160000</td>
#       <td id="T_0068e_row2_col2" class="data row2 col2" >800.000000</td>
#       <td id="T_0068e_row2_col3" class="data row2 col3" >1090.000000</td>
#       <td id="T_0068e_row2_col4" class="data row2 col4" >0.019000</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:INTERIOR DOOR
# Total thickness    :0.0254 m
# Total layers:[1]
# InsideAbsorpVis:[0.5]
# OutsideAbsorpVis:[0.5]
# OutsideAbsorpSolar:[0.5]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[4]
# <style type="text/css">
# </style>
# <table id="T_7660d_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7660d_row0_col0" class="data row0 col0" >G05 25MM WOOD</td>
#       <td id="T_7660d_row0_col1" class="data row0 col1" >0.150000</td>
#       <td id="T_7660d_row0_col2" class="data row0 col2" >608.000000</td>
#       <td id="T_7660d_row0_col3" class="data row0 col3" >1630.000000</td>
#       <td id="T_7660d_row0_col4" class="data row0 col4" >0.025400</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:INTERIOR PARTITION
# Total thickness    :0.0254 m
# Total layers:[1]
# InsideAbsorpVis:[0.5]
# OutsideAbsorpVis:[0.5]
# OutsideAbsorpSolar:[0.5]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[4]
# <style type="text/css">
# </style>
# <table id="T_3daea_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3daea_row0_col0" class="data row0 col0" >G05 25MM WOOD</td>
#       <td id="T_3daea_row0_col1" class="data row0 col1" >0.150000</td>
#       <td id="T_3daea_row0_col2" class="data row0 col2" >608.000000</td>
#       <td id="T_3daea_row0_col3" class="data row0 col3" >1630.000000</td>
#       <td id="T_3daea_row0_col4" class="data row0 col4" >0.025400</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:EXTSLABCARPET 4IN CLIMATEZONE 1-8
# Total thickness    :0.1016 m
# Total layers:[2]
# InsideAbsorpVis:[0.8]
# OutsideAbsorpVis:[0.85]
# OutsideAbsorpSolar:[0.85]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[2]
# <style type="text/css">
# </style>
# <table id="T_39a76_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_39a76_row0_col0" class="data row0 col0" >MAT-CC05 4 HW CONCRETE</td>
#       <td id="T_39a76_row0_col1" class="data row0 col1" >1.311000</td>
#       <td id="T_39a76_row0_col2" class="data row0 col2" >2240.000000</td>
#       <td id="T_39a76_row0_col3" class="data row0 col3" >836.800000</td>
#       <td id="T_39a76_row0_col4" class="data row0 col4" >0.101600</td>
#     </tr>
#     <tr>
#       <td id="T_39a76_row1_col0" class="data row1 col0" >CP02 CARPET PAD</td>
#       <td id="T_39a76_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_39a76_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_39a76_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_39a76_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 1
# Total thickness    :0.1803 m
# Total layers:[3]
# InsideAbsorpVis:[0.6]
# OutsideAbsorpVis:[0.7]
# OutsideAbsorpSolar:[0.7]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[1]
# <style type="text/css">
# </style>
# <table id="T_070d0_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_070d0_row0_col0" class="data row0 col0" >ROOF MEMBRANE</td>
#       <td id="T_070d0_row0_col1" class="data row0 col1" >0.160000</td>
#       <td id="T_070d0_row0_col2" class="data row0 col2" >1121.290000</td>
#       <td id="T_070d0_row0_col3" class="data row0 col3" >1460.000000</td>
#       <td id="T_070d0_row0_col4" class="data row0 col4" >0.009500</td>
#     </tr>
#     <tr>
#       <td id="T_070d0_row1_col0" class="data row1 col0" >ROOF INSULATION [18]</td>
#       <td id="T_070d0_row1_col1" class="data row1 col1" >0.049000</td>
#       <td id="T_070d0_row1_col2" class="data row1 col2" >265.000000</td>
#       <td id="T_070d0_row1_col3" class="data row1 col3" >836.800000</td>
#       <td id="T_070d0_row1_col4" class="data row1 col4" >0.169300</td>
#     </tr>
#     <tr>
#       <td id="T_070d0_row2_col0" class="data row2 col0" >METAL DECKING</td>
#       <td id="T_070d0_row2_col1" class="data row2 col1" >45.006000</td>
#       <td id="T_070d0_row2_col2" class="data row2 col2" >7680.000000</td>
#       <td id="T_070d0_row2_col3" class="data row2 col3" >418.400000</td>
#       <td id="T_070d0_row2_col4" class="data row2 col4" >0.001500</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 2
# Total thickness    :0.1803 m
# Total layers:[3]
# InsideAbsorpVis:[0.6]
# OutsideAbsorpVis:[0.7]
# OutsideAbsorpSolar:[0.7]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[1]
# <style type="text/css">
# </style>
# <table id="T_5544a_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5544a_row0_col0" class="data row0 col0" >ROOF MEMBRANE</td>
#       <td id="T_5544a_row0_col1" class="data row0 col1" >0.160000</td>
#       <td id="T_5544a_row0_col2" class="data row0 col2" >1121.290000</td>
#       <td id="T_5544a_row0_col3" class="data row0 col3" >1460.000000</td>
#       <td id="T_5544a_row0_col4" class="data row0 col4" >0.009500</td>
#     </tr>
#     <tr>
#       <td id="T_5544a_row1_col0" class="data row1 col0" >ROOF INSULATION [18]</td>
#       <td id="T_5544a_row1_col1" class="data row1 col1" >0.049000</td>
#       <td id="T_5544a_row1_col2" class="data row1 col2" >265.000000</td>
#       <td id="T_5544a_row1_col3" class="data row1 col3" >836.800000</td>
#       <td id="T_5544a_row1_col4" class="data row1 col4" >0.169300</td>
#     </tr>
#     <tr>
#       <td id="T_5544a_row2_col0" class="data row2 col0" >METAL DECKING</td>
#       <td id="T_5544a_row2_col1" class="data row2 col1" >45.006000</td>
#       <td id="T_5544a_row2_col2" class="data row2 col2" >7680.000000</td>
#       <td id="T_5544a_row2_col3" class="data row2 col3" >418.400000</td>
#       <td id="T_5544a_row2_col4" class="data row2 col4" >0.001500</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 2-5
# Total thickness    :0.2215 m
# Total layers:[3]
# InsideAbsorpVis:[0.6]
# OutsideAbsorpVis:[0.7]
# OutsideAbsorpSolar:[0.7]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[1]
# <style type="text/css">
# </style>
# <table id="T_478ff_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_478ff_row0_col0" class="data row0 col0" >ROOF MEMBRANE</td>
#       <td id="T_478ff_row0_col1" class="data row0 col1" >0.160000</td>
#       <td id="T_478ff_row0_col2" class="data row0 col2" >1121.290000</td>
#       <td id="T_478ff_row0_col3" class="data row0 col3" >1460.000000</td>
#       <td id="T_478ff_row0_col4" class="data row0 col4" >0.009500</td>
#     </tr>
#     <tr>
#       <td id="T_478ff_row1_col0" class="data row1 col0" >ROOF INSULATION [21]</td>
#       <td id="T_478ff_row1_col1" class="data row1 col1" >0.049000</td>
#       <td id="T_478ff_row1_col2" class="data row1 col2" >265.000000</td>
#       <td id="T_478ff_row1_col3" class="data row1 col3" >836.800000</td>
#       <td id="T_478ff_row1_col4" class="data row1 col4" >0.210500</td>
#     </tr>
#     <tr>
#       <td id="T_478ff_row2_col0" class="data row2 col0" >METAL DECKING</td>
#       <td id="T_478ff_row2_col1" class="data row2 col1" >45.006000</td>
#       <td id="T_478ff_row2_col2" class="data row2 col2" >7680.000000</td>
#       <td id="T_478ff_row2_col3" class="data row2 col3" >418.400000</td>
#       <td id="T_478ff_row2_col4" class="data row2 col4" >0.001500</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 3
# Total thickness    :0.1803 m
# Total layers:[3]
# InsideAbsorpVis:[0.6]
# OutsideAbsorpVis:[0.7]
# OutsideAbsorpSolar:[0.7]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[1]
# <style type="text/css">
# </style>
# <table id="T_40ec4_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_40ec4_row0_col0" class="data row0 col0" >ROOF MEMBRANE</td>
#       <td id="T_40ec4_row0_col1" class="data row0 col1" >0.160000</td>
#       <td id="T_40ec4_row0_col2" class="data row0 col2" >1121.290000</td>
#       <td id="T_40ec4_row0_col3" class="data row0 col3" >1460.000000</td>
#       <td id="T_40ec4_row0_col4" class="data row0 col4" >0.009500</td>
#     </tr>
#     <tr>
#       <td id="T_40ec4_row1_col0" class="data row1 col0" >ROOF INSULATION [18]</td>
#       <td id="T_40ec4_row1_col1" class="data row1 col1" >0.049000</td>
#       <td id="T_40ec4_row1_col2" class="data row1 col2" >265.000000</td>
#       <td id="T_40ec4_row1_col3" class="data row1 col3" >836.800000</td>
#       <td id="T_40ec4_row1_col4" class="data row1 col4" >0.169300</td>
#     </tr>
#     <tr>
#       <td id="T_40ec4_row2_col0" class="data row2 col0" >METAL DECKING</td>
#       <td id="T_40ec4_row2_col1" class="data row2 col1" >45.006000</td>
#       <td id="T_40ec4_row2_col2" class="data row2 col2" >7680.000000</td>
#       <td id="T_40ec4_row2_col3" class="data row2 col3" >418.400000</td>
#       <td id="T_40ec4_row2_col4" class="data row2 col4" >0.001500</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 4
# Total thickness    :0.1803 m
# Total layers:[3]
# InsideAbsorpVis:[0.6]
# OutsideAbsorpVis:[0.7]
# OutsideAbsorpSolar:[0.7]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[1]
# <style type="text/css">
# </style>
# <table id="T_a8847_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a8847_row0_col0" class="data row0 col0" >ROOF MEMBRANE</td>
#       <td id="T_a8847_row0_col1" class="data row0 col1" >0.160000</td>
#       <td id="T_a8847_row0_col2" class="data row0 col2" >1121.290000</td>
#       <td id="T_a8847_row0_col3" class="data row0 col3" >1460.000000</td>
#       <td id="T_a8847_row0_col4" class="data row0 col4" >0.009500</td>
#     </tr>
#     <tr>
#       <td id="T_a8847_row1_col0" class="data row1 col0" >ROOF INSULATION [18]</td>
#       <td id="T_a8847_row1_col1" class="data row1 col1" >0.049000</td>
#       <td id="T_a8847_row1_col2" class="data row1 col2" >265.000000</td>
#       <td id="T_a8847_row1_col3" class="data row1 col3" >836.800000</td>
#       <td id="T_a8847_row1_col4" class="data row1 col4" >0.169300</td>
#     </tr>
#     <tr>
#       <td id="T_a8847_row2_col0" class="data row2 col0" >METAL DECKING</td>
#       <td id="T_a8847_row2_col1" class="data row2 col1" >45.006000</td>
#       <td id="T_a8847_row2_col2" class="data row2 col2" >7680.000000</td>
#       <td id="T_a8847_row2_col3" class="data row2 col3" >418.400000</td>
#       <td id="T_a8847_row2_col4" class="data row2 col4" >0.001500</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTROOF IEAD CLIMATEZONE 7-8
# Total thickness    :0.3051 m
# Total layers:[3]
# InsideAbsorpVis:[0.6]
# OutsideAbsorpVis:[0.7]
# OutsideAbsorpSolar:[0.7]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[1]
# <style type="text/css">
# </style>
# <table id="T_137a0_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_137a0_row0_col0" class="data row0 col0" >ROOF MEMBRANE</td>
#       <td id="T_137a0_row0_col1" class="data row0 col1" >0.160000</td>
#       <td id="T_137a0_row0_col2" class="data row0 col2" >1121.290000</td>
#       <td id="T_137a0_row0_col3" class="data row0 col3" >1460.000000</td>
#       <td id="T_137a0_row0_col4" class="data row0 col4" >0.009500</td>
#     </tr>
#     <tr>
#       <td id="T_137a0_row1_col0" class="data row1 col0" >ROOF INSULATION [26]</td>
#       <td id="T_137a0_row1_col1" class="data row1 col1" >0.049000</td>
#       <td id="T_137a0_row1_col2" class="data row1 col2" >265.000000</td>
#       <td id="T_137a0_row1_col3" class="data row1 col3" >836.800000</td>
#       <td id="T_137a0_row1_col4" class="data row1 col4" >0.294100</td>
#     </tr>
#     <tr>
#       <td id="T_137a0_row2_col0" class="data row2 col0" >METAL DECKING</td>
#       <td id="T_137a0_row2_col1" class="data row2 col1" >45.006000</td>
#       <td id="T_137a0_row2_col2" class="data row2 col2" >7680.000000</td>
#       <td id="T_137a0_row2_col3" class="data row2 col3" >418.400000</td>
#       <td id="T_137a0_row2_col4" class="data row2 col4" >0.001500</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTROOF METAL CLIMATEZONE 6
# Total thickness    :0.266 m
# Total layers:[3]
# InsideAbsorpVis:[0.6]
# OutsideAbsorpVis:[0.6]
# OutsideAbsorpSolar:[0.6]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[4]
# <style type="text/css">
# </style>
# <table id="T_7d0c2_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7d0c2_row0_col0" class="data row0 col0" >METAL ROOFING</td>
#       <td id="T_7d0c2_row0_col1" class="data row0 col1" >45.006000</td>
#       <td id="T_7d0c2_row0_col2" class="data row0 col2" >7680.000000</td>
#       <td id="T_7d0c2_row0_col3" class="data row0 col3" >418.400000</td>
#       <td id="T_7d0c2_row0_col4" class="data row0 col4" >0.001500</td>
#     </tr>
#     <tr>
#       <td id="T_7d0c2_row1_col0" class="data row1 col0" >ROOF INSULATION [25]</td>
#       <td id="T_7d0c2_row1_col1" class="data row1 col1" >0.049000</td>
#       <td id="T_7d0c2_row1_col2" class="data row1 col2" >265.000000</td>
#       <td id="T_7d0c2_row1_col3" class="data row1 col3" >836.800000</td>
#       <td id="T_7d0c2_row1_col4" class="data row1 col4" >0.263000</td>
#     </tr>
#     <tr>
#       <td id="T_7d0c2_row2_col0" class="data row2 col0" >METAL DECKING</td>
#       <td id="T_7d0c2_row2_col1" class="data row2 col1" >45.006000</td>
#       <td id="T_7d0c2_row2_col2" class="data row2 col2" >7680.000000</td>
#       <td id="T_7d0c2_row2_col3" class="data row2 col3" >418.400000</td>
#       <td id="T_7d0c2_row2_col4" class="data row2 col4" >0.001500</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:INTERIOR WINDOW
# Total thickness    :0.003 m
# Total layers:[1]
# InsideAbsorpVis:[0.]
# OutsideAbsorpVis:[0.]
# OutsideAbsorpSolar:[0.]
# InsideAbsorpThermal:[0.84]
# OutsideRoughness:[6]
# <style type="text/css">
# </style>
# <table id="T_f238e_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f238e_row0_col0" class="data row0 col0" >CLEAR 3MM</td>
#       <td id="T_f238e_row0_col1" class="data row0 col1" >0.900000</td>
#       <td id="T_f238e_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_f238e_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_f238e_row0_col4" class="data row0 col4" >0.003000</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTWINDOW CLIMATEZONE 1
# Total thickness    :0.003 m
# Total layers:[1]
# InsideAbsorpVis:[0.]
# OutsideAbsorpVis:[0.]
# OutsideAbsorpSolar:[0.]
# InsideAbsorpThermal:[0.985]
# OutsideRoughness:[6]
# <style type="text/css">
# </style>
# <table id="T_ccc9b_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ccc9b_row0_col0" class="data row0 col0" >THEORETICAL GLASS [167]</td>
#       <td id="T_ccc9b_row0_col1" class="data row0 col1" >2.107300</td>
#       <td id="T_ccc9b_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_ccc9b_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_ccc9b_row0_col4" class="data row0 col4" >0.003000</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTWINDOW CLIMATEZONE 2
# Total thickness    :0.003 m
# Total layers:[1]
# InsideAbsorpVis:[0.]
# OutsideAbsorpVis:[0.]
# OutsideAbsorpSolar:[0.]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[6]
# <style type="text/css">
# </style>
# <table id="T_549fb_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_549fb_row0_col0" class="data row0 col0" >THEORETICAL GLASS [197]</td>
#       <td id="T_549fb_row0_col1" class="data row0 col1" >0.041500</td>
#       <td id="T_549fb_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_549fb_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_549fb_row0_col4" class="data row0 col4" >0.003000</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTWINDOW CLIMATEZONE 3
# Total thickness    :0.003 m
# Total layers:[1]
# InsideAbsorpVis:[0.]
# OutsideAbsorpVis:[0.]
# OutsideAbsorpSolar:[0.]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[6]
# <style type="text/css">
# </style>
# <table id="T_b0c1a_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b0c1a_row0_col0" class="data row0 col0" >THEORETICAL GLASS [202]</td>
#       <td id="T_b0c1a_row0_col1" class="data row0 col1" >0.019200</td>
#       <td id="T_b0c1a_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_b0c1a_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_b0c1a_row0_col4" class="data row0 col4" >0.003000</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTWINDOW CLIMATEZONE 4-5
# Total thickness    :0.003 m
# Total layers:[1]
# InsideAbsorpVis:[0.]
# OutsideAbsorpVis:[0.]
# OutsideAbsorpSolar:[0.]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[6]
# <style type="text/css">
# </style>
# <table id="T_9de4c_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9de4c_row0_col0" class="data row0 col0" >THEORETICAL GLASS [207]</td>
#       <td id="T_9de4c_row0_col1" class="data row0 col1" >0.013300</td>
#       <td id="T_9de4c_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_9de4c_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_9de4c_row0_col4" class="data row0 col4" >0.003000</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTWINDOW CLIMATEZONE 6
# Total thickness    :0.003 m
# Total layers:[1]
# InsideAbsorpVis:[0.]
# OutsideAbsorpVis:[0.]
# OutsideAbsorpSolar:[0.]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[6]
# <style type="text/css">
# </style>
# <table id="T_85491_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_85491_row0_col0" class="data row0 col0" >THEORETICAL GLASS [216]</td>
#       <td id="T_85491_row0_col1" class="data row0 col1" >0.013300</td>
#       <td id="T_85491_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_85491_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_85491_row0_col4" class="data row0 col4" >0.003000</td>
#     </tr>
#   </tbody>
# </table>
# Construction system:ASHRAE 189.1-2009 EXTWINDOW CLIMATEZONE 7-8
# Total thickness    :0.003 m
# Total layers:[1]
# InsideAbsorpVis:[0.]
# OutsideAbsorpVis:[0.]
# OutsideAbsorpSolar:[0.]
# InsideAbsorpThermal:[0.9]
# OutsideRoughness:[6]
# <style type="text/css">
# </style>
# <table id="T_4ede7_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4ede7_row0_col0" class="data row0 col0" >THEORETICAL GLASS [221]</td>
#       <td id="T_4ede7_row0_col1" class="data row0 col1" >0.008900</td>
#       <td id="T_4ede7_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_4ede7_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_4ede7_row0_col4" class="data row0 col4" >0.003000</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.get_construction(['PS-05']) # items should be passed as lists
# Out:
# Construction system:PS-05
# Total thickness    :0.0 m
# Total layers:[]
# InsideAbsorpVis:[]
# OutsideAbsorpVis:[]
# OutsideAbsorpSolar:[]
# InsideAbsorpThermal:[]
# OutsideRoughness:[]
# <style type="text/css">
# </style>
# <table id="T_0f6e7_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >NameMaterial</th>
#       <th class="col_heading level0 col1" >Conductivity</th>
#       <th class="col_heading level0 col2" >Density</th>
#       <th class="col_heading level0 col3" >SpecHeat</th>
#       <th class="col_heading level0 col4" >Thickness</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
variables = ['To',"Ti"]
caso1 = df.get_data(variables)
caso1.plot(subplots=True,figsize=(12,12));

# %%
variables = df.vars
caso1 = df.get_data(variables)

fig, ax = plt.subplots(len(variables),figsize=(20,50))

for i,variable in enumerate(variables):
    ax[i].plot(caso1[variable].index,caso1[variable],'r.',label=variable)
    ax[i].legend()
