# %%
import sqlite3
import os
import csv
import sqlite3 as sql
import pandas as pd

# %%
import sqlite3
import os
import csv

print('\n**************************:')
print('AVAILABLE SQL FILES:')
sql_files = ["../data/eplusout.sql"]

for file in os.listdir(os.getcwd()):
  if file.endswith(".sql"):
    sql_files.append(file)
    print(file)

if not sql_files:
  print('NO .sql FILE FOUND IN THIS DIRECTORY. PLACE THE SQL FILE IN THE SAME DIRECTORY AS THIS PYTHON SCRIPT AND TRY AGAIN.')
  quit()
	
out_sql = input('\nEnter sql filename (press enter to use "' + sql_files[0] + '"):')
if not out_sql:
  out_sql = sql_files[0]

#validate input, try connecting to database
sql_path = os.path.join(os.getcwd(),out_sql)
conn = sqlite3.connect(sql_path)
c = conn.cursor()

print('\n**************************:')
print('AVAILABLE OUTPUT VARIABLES:')
vars_avail = c.execute('SELECT DISTINCT KeyValue,VariableName FROM ReportVariableDataDictionary').fetchall()

for v in vars_avail:
  print(v)
key_value = input('Enter a Key Value (example: ' + vars_avail[0][0] + '):')
variable_name = input('Enter a Variable (example: ' + vars_avail[0][1] + '):')
#print('selected',key_value,',',variable_name);

run_period_index = c.execute('SELECT EnvironmentPeriodIndex FROM EnvironmentPeriods WHERE EnvironmentType=3').fetchone()[0]
variable_index = c.execute("SELECT ReportVariableDataDictionaryIndex FROM ReportVariableDataDictionary WHERE VariableName=:variable_name AND KeyValue=:key_value",{"variable_name":variable_name, "key_value":key_value}).fetchone()[0]
values = c.execute("SELECT Value FROM ReportData WHERE TimeIndex IN (SELECT TimeIndex FROM Time WHERE Interval=60 AND EnvironmentPeriodIndex=:run_period_index) AND ReportDataDictionaryIndex=:variable_index",{"run_period_index":run_period_index, "variable_index":variable_index}).fetchall()
for v in values: 
  v = v[0]
  
output_filename = key_value + '_' + variable_name + '.csv'
#get rid of invalid characters for filenames
#could be done much more cleanly with re library, but don't want to import that
output_filename = output_filename.replace('/','')
output_filename = output_filename.replace(':','')
output_filename = output_filename.replace('*','')
output_filename = output_filename.replace('?','')
output_filename = output_filename.replace('"','')
output_filename = output_filename.replace('<','')
output_filename = output_filename.replace('>','')
output_filename = output_filename.replace('|','')

with open(output_filename, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(values)
print('values saved to: ' + output_filename);

# %%
file = "../data/eplusout.sql"



conn = sqlite3.connect(file)
c = conn.cursor()

# print('AVAILABLE OUTPUT VARIABLES:')
variables = c.execute('SELECT * FROM ReportVariableDataDictionary').fetchall()
# variables = c.execute('SELECT  DISTINCT * FROM ReportVariableDataDictionary').fetchall()

# for variable in variables:
#   print(variable)

# key_value = input('Enter a Key Value (example: ' + vars_avail[0][0] + '):')
key_value = 'N1AU401'
variable_name = 'Zone Mean Air Temperature'

# variable_name = input('Enter a Variable (example: ' + vars_avail[0][1] + '):')

run_period_index = c.execute('SELECT EnvironmentPeriodIndex FROM EnvironmentPeriods WHERE EnvironmentType=3').fetchone()[0]
variable_index = c.execute("SELECT ReportVariableDataDictionaryIndex FROM ReportVariableDataDictionary WHERE VariableName=:variable_name AND KeyValue=:key_value",{"variable_name":variable_name, "key_value":key_value}).fetchone()[0]
values = c.execute("SELECT Value FROM ReportData WHERE TimeIndex IN (SELECT TimeIndex FROM Time WHERE Interval=10 AND EnvironmentPeriodIndex=:run_period_index) AND ReportDataDictionaryIndex=:variable_index",{"run_period_index":run_period_index, "variable_index":variable_index}).fetchall()
for v in values: 
  v = v[0]
  
output_filename = key_value + '_' + variable_name + '.csv'
#get rid of invalid characters for filenames
#could be done much more cleanly with re library, but don't want to import that
output_filename = output_filename.replace('/','')
output_filename = output_filename.replace(':','')
output_filename = output_filename.replace('*','')
output_filename = output_filename.replace('?','')
output_filename = output_filename.replace('"','')
output_filename = output_filename.replace('<','')
output_filename = output_filename.replace('>','')
output_filename = output_filename.replace('|','')

with open(output_filename, 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerows(values)
print('values saved to: ' + output_filename)
# Out:
# values saved to: N1AU401_Zone Mean Air Temperature.csv

# %%
vars = c.execute('SELECT * FROM Time').fetchall()
len(vars)
# Out:
# 61697

# %%
run_period_index = c.execute('SELECT * FROM Time').fetchall()
run_period_index
# Out:
# [(1, 2006, 1, 1, 0, 10, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (2, 2006, 1, 1, 0, 20, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (3, 2006, 1, 1, 0, 30, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (4, 2006, 1, 1, 0, 40, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (5, 2006, 1, 1, 0, 50, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (6, 2006, 1, 1, 1, 0, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (7, 2006, 1, 1, 1, 0, 0, 60, 1, 1, 'Sunday', 1, 0),
#  (8, 2006, 1, 1, 1, 10, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (9, 2006, 1, 1, 1, 20, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (10, 2006, 1, 1, 1, 30, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (11, 2006, 1, 1, 1, 40, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (12, 2006, 1, 1, 1, 50, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (13, 2006, 1, 1, 2, 0, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (14, 2006, 1, 1, 2, 0, 0, 60, 1, 1, 'Sunday', 1, 0),
#  (15, 2006, 1, 1, 2, 10, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (16, 2006, 1, 1, 2, 20, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (17, 2006, 1, 1, 2, 30, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (18, 2006, 1, 1, 2, 40, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (19, 2006, 1, 1, 2, 50, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (20, 2006, 1, 1, 3, 0, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (21, 2006, 1, 1, 3, 0, 0, 60, 1, 1, 'Sunday', 1, 0),
#  (22, 2006, 1, 1, 3, 10, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (23, 2006, 1, 1, 3, 20, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (24, 2006, 1, 1, 3, 30, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (25, 2006, 1, 1, 3, 40, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (26, 2006, 1, 1, 3, 50, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (27, 2006, 1, 1, 4, 0, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (28, 2006, 1, 1, 4, 0, 0, 60, 1, 1, 'Sunday', 1, 0),
#  (29, 2006, 1, 1, 4, 10, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (30, 2006, 1, 1, 4, 20, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (31, 2006, 1, 1, 4, 30, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (32, 2006, 1, 1, 4, 40, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (33, 2006, 1, 1, 4, 50, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (34, 2006, 1, 1, 5, 0, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (35, 2006, 1, 1, 5, 0, 0, 60, 1, 1, 'Sunday', 1, 0),
#  (36, 2006, 1, 1, 5, 10, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (37, 2006, 1, 1, 5, 20, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (38, 2006, 1, 1, 5, 30, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (39, 2006, 1, 1, 5, 40, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (40, 2006, 1, 1, 5, 50, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (41, 2006, 1, 1, 6, 0, 0, 10, -1, 1, 'Sunday', 1, 0),
#  
 0, 10, -1, 1, 'Sunday', 1, 0),
#  (167, 2006, 1, 1, 24, 0, 0, 10, -1, 1, 'Sunday', 1, 0),
#  (168, 2006, 1, 1, 24, 0, 0, 60, 1, 1, 'Sunday', 1, 0),
#  (169, 2006, 1, 1, 24, 0, 0, 1440, 2, 1, 'Sunday', 1, 0),
#  (170, 2006, 1, 2, 0, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (171, 2006, 1, 2, 0, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (172, 2006, 1, 2, 0, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (173, 2006, 1, 2, 0, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (174, 2006, 1, 2, 0, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (175, 2006, 1, 2, 1, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (176, 2006, 1, 2, 1, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (177, 2006, 1, 2, 1, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (178, 2006, 1, 2, 1, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (179, 2006, 1, 2, 1, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (180, 2006, 1, 2, 1, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (181, 2006, 1, 2, 1, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (182, 2006, 1, 2, 2, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (183, 2006, 1, 2, 2, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (184, 2006, 1, 2, 2, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (185, 2006, 1, 2, 2, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (186, 2006, 1, 2, 2, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (187, 2006, 1, 2, 2, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (188, 2006, 1, 2, 2, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (189, 2006, 1, 2, 3, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (190, 2006, 1, 2, 3, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (191, 2006, 1, 2, 3, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (192, 2006, 1, 2, 3, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (193, 2006, 1, 2, 3, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (194, 2006, 1, 2, 3, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (195, 2006, 1, 2, 3, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (196, 2006, 1, 2, 4, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (197, 2006, 1, 2, 4, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (198, 2006, 1, 2, 4, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (199, 2006, 1, 2, 4, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (200, 2006, 1, 2, 4, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (201, 2006, 1, 2, 4, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (202, 2006, 1, 2, 4, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (203, 2006, 1, 2, 5, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (204, 2006, 1, 2, 5, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (205, 2006, 1, 2, 5, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (206, 2006, 1, 2, 5, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (207, 2006, 1, 2, 5, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (208, 2006, 1, 2, 5, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (209, 2006, 1, 2, 5, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (210, 2006, 1, 2, 6, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (211, 2006, 1, 2, 6, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (212, 2006, 1, 2, 6, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (213, 2006, 1, 2, 6, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (214, 2006, 1, 2, 6, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (215, 2006, 1, 2, 6, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (216, 2006, 1, 2, 6, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (217, 2006, 1, 2, 7, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (218, 2006, 1, 2, 7, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (219, 2006, 1, 2, 7, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (220, 2006, 1, 2, 7, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (221, 2006, 1, 2, 7, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (222, 2006, 1, 2, 7, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (223, 2006, 1, 2, 7, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (224, 2006, 1, 2, 8, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (225, 2006, 1, 2, 8, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (226, 2006, 1, 2, 8, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (227, 2006, 1, 2, 8, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (228, 2006, 1, 2, 8, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (229, 2006, 1, 2, 8, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (230, 2006, 1, 2, 8, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (231, 2006, 1, 2, 9, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (232, 2006, 1, 2, 9, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (233, 2006, 1, 2, 9, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (234, 2006, 1, 2, 9, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (235, 2006, 1, 2, 9, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (236, 2006, 1, 2, 9, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (237, 2006, 1, 2, 9, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (238, 2006, 1, 2, 10, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (239, 2006, 1, 2, 10, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (240, 2006, 1, 2, 10, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (241, 2006, 1, 2, 10, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (242, 2006, 1, 2, 10, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (243, 2006, 1, 2, 10, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (244, 2006, 1, 2, 10, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (245, 2006, 1, 2, 11, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (246, 2006, 1, 2, 11, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (247, 2006, 1, 2, 11, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (248, 2006, 1, 2, 11, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (249, 2006, 1, 2, 11, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (250, 2006, 1, 2, 11, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (251, 2006, 1, 2, 11, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (252, 2006, 1, 2, 12, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (253, 2006, 1, 2, 12, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (254, 2006, 1, 2, 12, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (255, 2006, 1, 2, 12, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (256, 2006, 1, 2, 12, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (257, 2006, 1, 2, 12, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (258, 2006, 1, 2, 12, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (259, 2006, 1, 2, 13, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (260, 2006, 1, 2, 13, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (261, 2006, 1, 2, 13, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (262, 2006, 1, 2, 13, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (263, 2006, 1, 2, 13, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (264, 2006, 1, 2, 13, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (265, 2006, 1, 2, 13, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (266, 2006, 1, 2, 14, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (267, 2006, 1, 2, 14, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (268, 2006, 1, 2, 14, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (269, 2006, 1, 2, 14, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (270, 2006, 1, 2, 14, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (271, 2006, 1, 2, 14, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (272, 2006, 1, 2, 14, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (273, 2006, 1, 2, 15, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (274, 2006, 1, 2, 15, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (275, 2006, 1, 2, 15, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (276, 2006, 1, 2, 15, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (277, 2006, 1, 2, 15, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (278, 2006, 1, 2, 15, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (279, 2006, 1, 2, 15, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (280, 2006, 1, 2, 16, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (281, 2006, 1, 2, 16, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (282, 2006, 1, 2, 16, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (283, 2006, 1, 2, 16, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (284, 2006, 1, 2, 16, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (285, 2006, 1, 2, 16, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (286, 2006, 1, 2, 16, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (287, 2006, 1, 2, 17, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (288, 2006, 1, 2, 17, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (289, 2006, 1, 2, 17, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (290, 2006, 1, 2, 17, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (291, 2006, 1, 2, 17, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (292, 2006, 1, 2, 17, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (293, 2006, 1, 2, 17, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (294, 2006, 1, 2, 18, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (295, 2006, 1, 2, 18, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (296, 2006, 1, 2, 18, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (297, 2006, 1, 2, 18, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (298, 2006, 1, 2, 18, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (299, 2006, 1, 2, 18, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (300, 2006, 1, 2, 18, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (301, 2006, 1, 2, 19, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (302, 2006, 1, 2, 19, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (303, 2006, 1, 2, 19, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (304, 2006, 1, 2, 19, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (305, 2006, 1, 2, 19, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (306, 2006, 1, 2, 19, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (307, 2006, 1, 2, 19, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (308, 2006, 1, 2, 20, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (309, 2006, 1, 2, 20, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (310, 2006, 1, 2, 20, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (311, 2006, 1, 2, 20, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (312, 2006, 1, 2, 20, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (313, 2006, 1, 2, 20, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (314, 2006, 1, 2, 20, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (315, 2006, 1, 2, 21, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (316, 2006, 1, 2, 21, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (317, 2006, 1, 2, 21, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (318, 2006, 1, 2, 21, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (319, 2006, 1, 2, 21, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (320, 2006, 1, 2, 21, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (321, 2006, 1, 2, 21, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (322, 2006, 1, 2, 22, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (323, 2006, 1, 2, 22, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (324, 2006, 1, 2, 22, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (325, 2006, 1, 2, 22, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (326, 2006, 1, 2, 22, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (327, 2006, 1, 2, 22, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (328, 2006, 1, 2, 22, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (329, 2006, 1, 2, 23, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (330, 2006, 1, 2, 23, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (331, 2006, 1, 2, 23, 10, 0, 10, -1, 2, 'Monday', 1, 0),
#  (332, 2006, 1, 2, 23, 20, 0, 10, -1, 2, 'Monday', 1, 0),
#  (333, 2006, 1, 2, 23, 30, 0, 10, -1, 2, 'Monday', 1, 0),
#  (334, 2006, 1, 2, 23, 40, 0, 10, -1, 2, 'Monday', 1, 0),
#  (335, 2006, 1, 2, 23, 50, 0, 10, -1, 2, 'Monday', 1, 0),
#  (336, 2006, 1, 2, 24, 0, 0, 10, -1, 2, 'Monday', 1, 0),
#  (337, 2006, 1, 2, 24, 0, 0, 60, 1, 2, 'Monday', 1, 0),
#  (338, 2006, 1, 2, 24, 0, 0, 1440, 2, 2, 'Monday', 1, 0),
#  (339, 2006, 1, 3, 0, 10, 0, 10, -1, 3, 'Tuesday', 1, 0),
#  
 0, 10, -1, 5, 'Thursday', 1, 0),
#  (787, 2006, 1, 5, 16, 0, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (788, 2006, 1, 5, 16, 0, 0, 60, 1, 5, 'Thursday', 1, 0),
#  (789, 2006, 1, 5, 16, 10, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (790, 2006, 1, 5, 16, 20, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (791, 2006, 1, 5, 16, 30, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (792, 2006, 1, 5, 16, 40, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (793, 2006, 1, 5, 16, 50, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (794, 2006, 1, 5, 17, 0, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (795, 2006, 1, 5, 17, 0, 0, 60, 1, 5, 'Thursday', 1, 0),
#  (796, 2006, 1, 5, 17, 10, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (797, 2006, 1, 5, 17, 20, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (798, 2006, 1, 5, 17, 30, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (799, 2006, 1, 5, 17, 40, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (800, 2006, 1, 5, 17, 50, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (801, 2006, 1, 5, 18, 0, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (802, 2006, 1, 5, 18, 0, 0, 60, 1, 5, 'Thursday', 1, 0),
#  (803, 2006, 1, 5, 18, 10, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (804, 2006, 1, 5, 18, 20, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (805, 2006, 1, 5, 18, 30, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (806, 2006, 1, 5, 18, 40, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (807, 2006, 1, 5, 18, 50, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (808, 2006, 1, 5, 19, 0, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (809, 2006, 1, 5, 19, 0, 0, 60, 1, 5, 'Thursday', 1, 0),
#  (810, 2006, 1, 5, 19, 10, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (811, 2006, 1, 5, 19, 20, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (812, 2006, 1, 5, 19, 30, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (813, 2006, 1, 5, 19, 40, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (814, 2006, 1, 5, 19, 50, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (815, 2006, 1, 5, 20, 0, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (816, 2006, 1, 5, 20, 0, 0, 60, 1, 5, 'Thursday', 1, 0),
#  (817, 2006, 1, 5, 20, 10, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (818, 2006, 1, 5, 20, 20, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (819, 2006, 1, 5, 20, 30, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (820, 2006, 1, 5, 20, 40, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (821, 2006, 1, 5, 20, 50, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (822, 2006, 1, 5, 21, 0, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (823, 2006, 1, 5, 21, 0, 0, 60, 1, 5, 'Thursday', 1, 0),
#  (824, 2006, 1, 5, 21, 10, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (825, 2006, 1, 5, 21, 20, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (826, 2006, 1, 5, 21, 30, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (827, 2006, 1, 5, 21, 40, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (828, 2006, 1, 5, 21, 50, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (829, 2006, 1, 5, 22, 0, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (830, 2006, 1, 5, 22, 0, 0, 60, 1, 5, 'Thursday', 1, 0),
#  (831, 2006, 1, 5, 22, 10, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (832, 2006, 1, 5, 22, 20, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (833, 2006, 1, 5, 22, 30, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (834, 2006, 1, 5, 22, 40, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (835, 2006, 1, 5, 22, 50, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (836, 2006, 1, 5, 23, 0, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (837, 2006, 1, 5, 23, 0, 0, 60, 1, 5, 'Thursday', 1, 0),
#  (838, 2006, 1, 5, 23, 10, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (839, 2006, 1, 5, 23, 20, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (840, 2006, 1, 5, 23, 30, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (841, 2006, 1, 5, 23, 40, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (842, 2006, 1, 5, 23, 50, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (843, 2006, 1, 5, 24, 0, 0, 10, -1, 5, 'Thursday', 1, 0),
#  (844, 2006, 1, 5, 24, 0, 0, 60, 1, 5, 'Thursday', 1, 0),
#  (845, 2006, 1, 5, 24, 0, 0, 1440, 2, 5, 'Thursday', 1, 0),
#  (846, 2006, 1, 6, 0, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (847, 2006, 1, 6, 0, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (848, 2006, 1, 6, 0, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (849, 2006, 1, 6, 0, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (850, 2006, 1, 6, 0, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (851, 2006, 1, 6, 1, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (852, 2006, 1, 6, 1, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (853, 2006, 1, 6, 1, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (854, 2006, 1, 6, 1, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (855, 2006, 1, 6, 1, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (856, 2006, 1, 6, 1, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (857, 2006, 1, 6, 1, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (858, 2006, 1, 6, 2, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (859, 2006, 1, 6, 2, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (860, 2006, 1, 6, 2, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (861, 2006, 1, 6, 2, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (862, 2006, 1, 6, 2, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (863, 2006, 1, 6, 2, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (864, 2006, 1, 6, 2, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (865, 2006, 1, 6, 3, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (866, 2006, 1, 6, 3, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (867, 2006, 1, 6, 3, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (868, 2006, 1, 6, 3, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (869, 2006, 1, 6, 3, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (870, 2006, 1, 6, 3, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (871, 2006, 1, 6, 3, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (872, 2006, 1, 6, 4, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (873, 2006, 1, 6, 4, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (874, 2006, 1, 6, 4, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (875, 2006, 1, 6, 4, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (876, 2006, 1, 6, 4, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (877, 2006, 1, 6, 4, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (878, 2006, 1, 6, 4, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (879, 2006, 1, 6, 5, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (880, 2006, 1, 6, 5, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (881, 2006, 1, 6, 5, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (882, 2006, 1, 6, 5, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (883, 2006, 1, 6, 5, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (884, 2006, 1, 6, 5, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (885, 2006, 1, 6, 5, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (886, 2006, 1, 6, 6, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (887, 2006, 1, 6, 6, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (888, 2006, 1, 6, 6, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (889, 2006, 1, 6, 6, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (890, 2006, 1, 6, 6, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (891, 2006, 1, 6, 6, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (892, 2006, 1, 6, 6, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (893, 2006, 1, 6, 7, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (894, 2006, 1, 6, 7, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (895, 2006, 1, 6, 7, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (896, 2006, 1, 6, 7, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (897, 2006, 1, 6, 7, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (898, 2006, 1, 6, 7, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (899, 2006, 1, 6, 7, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (900, 2006, 1, 6, 8, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (901, 2006, 1, 6, 8, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (902, 2006, 1, 6, 8, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (903, 2006, 1, 6, 8, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (904, 2006, 1, 6, 8, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (905, 2006, 1, 6, 8, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (906, 2006, 1, 6, 8, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (907, 2006, 1, 6, 9, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (908, 2006, 1, 6, 9, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (909, 2006, 1, 6, 9, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (910, 2006, 1, 6, 9, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (911, 2006, 1, 6, 9, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (912, 2006, 1, 6, 9, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (913, 2006, 1, 6, 9, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (914, 2006, 1, 6, 10, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (915, 2006, 1, 6, 10, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (916, 2006, 1, 6, 10, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (917, 2006, 1, 6, 10, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (918, 2006, 1, 6, 10, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (919, 2006, 1, 6, 10, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (920, 2006, 1, 6, 10, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (921, 2006, 1, 6, 11, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (922, 2006, 1, 6, 11, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (923, 2006, 1, 6, 11, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (924, 2006, 1, 6, 11, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (925, 2006, 1, 6, 11, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (926, 2006, 1, 6, 11, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (927, 2006, 1, 6, 11, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (928, 2006, 1, 6, 12, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (929, 2006, 1, 6, 12, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (930, 2006, 1, 6, 12, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (931, 2006, 1, 6, 12, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (932, 2006, 1, 6, 12, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (933, 2006, 1, 6, 12, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (934, 2006, 1, 6, 12, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (935, 2006, 1, 6, 13, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (936, 2006, 1, 6, 13, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (937, 2006, 1, 6, 13, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (938, 2006, 1, 6, 13, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (939, 2006, 1, 6, 13, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (940, 2006, 1, 6, 13, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (941, 2006, 1, 6, 13, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (942, 2006, 1, 6, 14, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (943, 2006, 1, 6, 14, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (944, 2006, 1, 6, 14, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (945, 2006, 1, 6, 14, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (946, 2006, 1, 6, 14, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (947, 2006, 1, 6, 14, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (948, 2006, 1, 6, 14, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (949, 2006, 1, 6, 15, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (950, 2006, 1, 6, 15, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (951, 2006, 1, 6, 15, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (952, 2006, 1, 6, 15, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (953, 2006, 1, 6, 15, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (954, 2006, 1, 6, 15, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (955, 2006, 1, 6, 15, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (956, 2006, 1, 6, 16, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (957, 2006, 1, 6, 16, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (958, 2006, 1, 6, 16, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (959, 2006, 1, 6, 16, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (960, 2006, 1, 6, 16, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (961, 2006, 1, 6, 16, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (962, 2006, 1, 6, 16, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (963, 2006, 1, 6, 17, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (964, 2006, 1, 6, 17, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (965, 2006, 1, 6, 17, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (966, 2006, 1, 6, 17, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (967, 2006, 1, 6, 17, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (968, 2006, 1, 6, 17, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (969, 2006, 1, 6, 17, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (970, 2006, 1, 6, 18, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (971, 2006, 1, 6, 18, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (972, 2006, 1, 6, 18, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (973, 2006, 1, 6, 18, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (974, 2006, 1, 6, 18, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (975, 2006, 1, 6, 18, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (976, 2006, 1, 6, 18, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (977, 2006, 1, 6, 19, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (978, 2006, 1, 6, 19, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (979, 2006, 1, 6, 19, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (980, 2006, 1, 6, 19, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (981, 2006, 1, 6, 19, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (982, 2006, 1, 6, 19, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (983, 2006, 1, 6, 19, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (984, 2006, 1, 6, 20, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (985, 2006, 1, 6, 20, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (986, 2006, 1, 6, 20, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (987, 2006, 1, 6, 20, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (988, 2006, 1, 6, 20, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (989, 2006, 1, 6, 20, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (990, 2006, 1, 6, 20, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (991, 2006, 1, 6, 21, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (992, 2006, 1, 6, 21, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (993, 2006, 1, 6, 21, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  (994, 2006, 1, 6, 21, 20, 0, 10, -1, 6, 'Friday', 1, 0),
#  (995, 2006, 1, 6, 21, 30, 0, 10, -1, 6, 'Friday', 1, 0),
#  (996, 2006, 1, 6, 21, 40, 0, 10, -1, 6, 'Friday', 1, 0),
#  (997, 2006, 1, 6, 21, 50, 0, 10, -1, 6, 'Friday', 1, 0),
#  (998, 2006, 1, 6, 22, 0, 0, 10, -1, 6, 'Friday', 1, 0),
#  (999, 2006, 1, 6, 22, 0, 0, 60, 1, 6, 'Friday', 1, 0),
#  (1000, 2006, 1, 6, 22, 10, 0, 10, -1, 6, 'Friday', 1, 0),
#  ...]

# %%
for i, variable in enumerate(variables):
    print(i,variable)

# %%
variables = c.execute('SELECT Time.Year, Time.Month, Time.Day, Time.Minute, Time.DayType, ReportDataDictionary.KeyValue, ReportDataDictionary.Name, ReportDataDictionary.Units, ReportData.Value
FROM (ReportData INNER JOIN ReportDataDictionary ON ReportData.ReportDataDictionaryIndex = ReportDataDictionary.ReportDataDictionaryIndex) INNER JOIN Time ON ReportData.TimeIndex = Time.TimeIndex').fetchall()

variables
# Out:
#   File "<ipython-input-31-998c61bd0e06>", line 1
#     variables = c.execute('SELECT Time.Year, Time.Month, Time.Day, Time.Minute, Time.DayType, ReportDataDictionary.KeyValue, ReportDataDictionary.Name, ReportDataDictionary.Units, ReportData.Value
#                                                                                                                                                                                                     ^
# SyntaxError: EOL while scanning string literal

# %%
myconn = sql.connect(file)
mycursor = myconn.cursor()
comando = """SELECT Time.Year, Time.Month, Time.Day, Time.Minute, Time.DayType, ReportDataDictionary.KeyValue,
  ReportDataDictionary.Name, ReportDataDictionary.Units, ReportData.Value
  FROM (ReportData INNER JOIN ReportDataDictionary ON ReportData.ReportDataDictionaryIndex = ReportDataDictionary.ReportDataDictionaryIndex) 
  INNER JOIN Time ON ReportData.TimeIndex = Time.TimeIndex"""
mycursor.execute(comando)
data = mycursor.fetchall()
# df = pd.DataFrame(data)

# %%
data[0][2]
# Out:
# 1
