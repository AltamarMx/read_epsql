# %%
import sqlite3
import os 
import csv
import sqlite3 as sql
import pandas as pd

# %%
# file = "../data/eplusout.sql"



# conn = sqlite3.connect(file)
# c = conn.cursor()

# # print('AVAILABLE OUTPUT VARIABLES:')
# variables = c.execute('SELECT * FROM ReportVariableDataDictionary').fetchall()
# # variables = c.execute('SELECT  DISTINCT * FROM ReportVariableDataDictionary').fetchall()

# # for variable in variables:
# #   print(variable)

# # key_value = input('Enter a Key Value (example: ' + vars_avail[0][0] + '):')
# key_value = 'N1AU401'
# variable_name = 'Zone Mean Air Temperature'

# # variable_name = input('Enter a Variable (example: ' + vars_avail[0][1] + '):')

# run_period_index = c.execute('SELECT EnvironmentPeriodIndex FROM EnvironmentPeriods WHERE EnvironmentType=3').fetchone()[0]
# variable_index = c.execute("SELECT ReportVariableDataDictionaryIndex FROM ReportVariableDataDictionary WHERE VariableName=:variable_name AND KeyValue=:key_value",{"variable_name":variable_name, "key_value":key_value}).fetchone()[0]
# values = c.execute("SELECT Value FROM ReportData WHERE TimeIndex IN (SELECT TimeIndex FROM Time WHERE Interval=10 AND EnvironmentPeriodIndex=:run_period_index) AND ReportDataDictionaryIndex=:variable_index",{"run_period_index":run_period_index, "variable_index":variable_index}).fetchall()
# for v in values: 
#   v = v[0]
  
# output_filename = key_value + '_' + variable_name + '.csv'
# #get rid of invalid characters for filenames
# #could be done much more cleanly with re library, but don't want to import that
# output_filename = output_filename.replace('/','')
# output_filename = output_filename.replace(':','')
# output_filename = output_filename.replace('*','')
# output_filename = output_filename.replace('?','')
# output_filename = output_filename.replace('"','')
# output_filename = output_filename.replace('<','')
# output_filename = output_filename.replace('>','')
# output_filename = output_filename.replace('|','')

# with open(output_filename, 'w', newline='') as f:
#     writer = csv.writer(f)
#     writer.writerows(values)
# print('values saved to: ' + output_filename)

# %%
# vars = c.execute('SELECT * FROM Time').fetchall()
# len(vars)

# %%
# run_period_index = c.execute('SELECT * FROM Time').fetchall()
# run_period_index

# %%
# for i, variable in enumerate(variables):
#     print(i,variable)

# %%
# variables = c.execute('SELECT Time.Year, Time.Month, Time.Day, Time.Minute, Time.DayType, ReportDataDictionary.KeyValue, ReportDataDictionary.Name, ReportDataDictionary.Units, ReportData.Value
# FROM (ReportData INNER JOIN ReportDataDictionary ON ReportData.ReportDataDictionaryIndex = ReportDataDictionary.ReportDataDictionaryIndex) INNER JOIN Time ON ReportData.TimeIndex = Time.TimeIndex').fetchall()

# variables

# %%
file = "../data/eplusout.sql"

myconn = sql.connect(file)
mycursor = myconn.cursor()
comando = """SELECT Time.Year, Time.Month, Time.Day, Time.Minute, Time.DayType, ReportDataDictionary.KeyValue,
  ReportDataDictionary.Name, ReportDataDictionary.Units, ReportData.Value
  FROM (ReportData INNER JOIN ReportDataDictionary ON ReportData.ReportDataDictionaryIndex = ReportDataDictionary.ReportDataDictionaryIndex) 
  INNER JOIN Time ON ReportData.TimeIndex = Time.TimeIndex"""
mycursor.execute(comando)
data = mycursor.fetchall()
# df = pd.DataFrame(data)

# %%
data
# Out:
# [(2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.966260853042783),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   25.425423417325266),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   25.610683800852463),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.976682325946076),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   27.549215770329187),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   27.382058572523594),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   27.57156589888446),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.582022928304053),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   24.059239251811032),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   24.277200573487658),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   23.184524077708776),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.77077734965772),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.15242115253693),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   24.283281807099133),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.697320793416676),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   23.394414167700713),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   28.20199811558092),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   28.639204446512014),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.92148752112703),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   26.28613160775624),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.46754263429684),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   24.289524439707563),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   26.466360688611005),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   25.07880706906925),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   27.436578612742853),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.908318092881842),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   25.368688402441187),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   25.55421044744728),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.922144576445312),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   27.483820544601304),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   27.317926706105297),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   27.506947273365725),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.540217969875407),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   24.017801109197194),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   24.23515898714203),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   23.06934848716428),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.71424362266173),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.094016474160348),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   24.237508777000787),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.573065190866036),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   23.34946229076704),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   28.139218215368974),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   28.583875498485778),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.90437344451125),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   26.186611878514423),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.408747235460538),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   24.23931880274173),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   26.385532218496344),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   25.015417890515927),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   27.324111415836384),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.848171160866357),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   25.31031840706413),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   25.495250484403414),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.866265725986214),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   27.413950143194597),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   27.250459630856284),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   27.438101781601272),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.500089980853076),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.977940590366373),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   24.194102615225656),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   23.007814918252222),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.657998617748106),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.037453640947938),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   24.192384158054047),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.443785597862753),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   23.30708194736797),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   28.070643417312354),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   28.52077353003888),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.886439605928718),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   26.087521423488834),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.35195999105048),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   24.19056283350329),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   26.304752895900986),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.95203682689381),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   27.204562918587026),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.800773780030493),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   25.2646111986095),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   25.448922029693563),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.823099005307288),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   27.357809583040478),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   27.19639148403786),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   27.3827259324275),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.472981694338102),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.95090967729646),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   24.165858802887545),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   22.988268823252895),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.614234208166124),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   24.992472700981736),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   24.156429143582756),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.33168908535115),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   23.277728122414896),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   28.00429704712281),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   28.46049895543047),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.867690715225862),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   26.002220620036997),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.308605076637303),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   24.154350564446187),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   26.237417312324308),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.90160259420975),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   27.10421071971696),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.789902690464796),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   25.25417302362603),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   25.438572860917375),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.815036557736256),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   27.339036234646326),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   27.17837620596569),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   27.364496044704392),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.477995967639526),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.955420391828266),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   24.169657645216795),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   23.062393912307577),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.603457787702137),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   24.977187844753434),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   24.14385005781415),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.262837768808428),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   23.279397249874123),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.94749504812561),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   28.412876175043433),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.84849487047602),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   25.951408706677626),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.299437854916896),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   24.14973888585239),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   26.205309617226238),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.88533687190086),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   27.05524609092115),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.789588380992676),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   25.252750096686427),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   25.4370713524657),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.815913651270563),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   27.326437253079117),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   27.166411638019838),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   27.352126969678174),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.490344850283574),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.966224782600325),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   24.17957724629514),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   23.100415004490085),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.6015493113159),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   24.969708034734417),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   24.133725889021694),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.195560407268918),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   23.286702972236814),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.89220306721529),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   28.367890933476236),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.829286886178316),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   25.904658879993747),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.29908738576975),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   24.151954606391584),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   26.178673555191374),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.877482764659494),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   27.011364156273732),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU401',
#   'Zone Air Temperature',
#   'C',
#   24.85050249304649),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU402',
#   'Zone Air Temperature',
#   'C',
#   25.312660757625423),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU403',
#   'Zone Air Temperature',
#   'C',
#   25.497451829296633),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU404',
#   'Zone Air Temperature',
#   'C',
#   24.86985697378195),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU101',
#   'Zone Air Temperature',
#   'C',
#   27.411711588148503),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU102',
#   'Zone Air Temperature',
#   'C',
#   27.248604039584762),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU103',
#   'Zone Air Temperature',
#   'C',
#   27.43599398344359),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU201',
#   'Zone Air Temperature',
#   'C',
#   23.510608898548956),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU202',
#   'Zone Air Temperature',
#   'C',
#   23.987922633849944),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU203',
#   'Zone Air Temperature',
#   'C',
#   24.203592645042473),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Air Temperature',
#   'C',
#   23.06879420386264),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2STR',
#   'Zone Air Temperature',
#   'C',
#   24.660376816208622),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBADM',
#   'Zone Air Temperature',
#   'C',
#   25.037209974685798),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Air Temperature',
#   'C',
#   24.191196638762094),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Air Temperature',
#   'C',
#   27.417376473928993),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Air Temperature',
#   'C',
#   23.315797791726926),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Air Temperature',
#   'C',
#   28.042642485120993),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Air Temperature',
#   'C',
#   28.49751992316447),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Air Temperature',
#   'C',
#   25.8762955072412),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBIMP',
#   'Zone Air Temperature',
#   'C',
#   26.069758852744645),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSCOM',
#   'Zone Air Temperature',
#   'C',
#   23.355896696355302),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Air Temperature',
#   'C',
#   24.195908355440462),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Air Temperature',
#   'C',
#   26.29634104795838),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSTR',
#   'Zone Air Temperature',
#   'C',
#   24.951780669541517),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Air Temperature',
#   'C',
#   27.18934565234635),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.78240337401605),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   25.24377541355143),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   25.4276119335008),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.809294449450164),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   27.302895756594065),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   27.14383095503541),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   27.32881059184849),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.49413507858715),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.968163012071802),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   24.180389605904477),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   23.086221670624667),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.592516867092943),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   24.95555502124291),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   24.115828301528058),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.115092024560592),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   23.284990988154338),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.834733269741765),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   28.32038093398669),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.810136548687527),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   25.84683500102265),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.290623565566975),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   24.145953417806286),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   26.142215445537776),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.861850129865946),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   26.952691535646945),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.769699739788),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   25.22946081410054),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   25.41298393832031),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.796795834693302),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   27.276376995424048),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   27.117671898549595),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   27.30241526774723),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.490304656631995),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.96290794821459),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   24.174294201634396),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   23.061387634403548),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.5775790198734),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   24.934808708270246),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   24.094011172704025),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.036251058177104),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   23.27582839597054),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.778902535274796),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   28.274795134026736),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.790894676216514),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   25.784935470001628),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.274296416368315),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   24.132656893246292),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   26.10209567004139),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.83989083773737),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   26.89484556716253),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.69641531916284),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   25.15712687500137),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   25.33874101552746),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.725559255336933),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   27.186942379983854),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   27.031197056692974),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   27.214003608359693),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.43266882737991),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.90571246623873),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   24.11512606248356),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   22.848825093903887),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.508227829960752),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   24.865945802649797),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   24.02926795036336),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   26.88906952412973),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   23.2140653878724),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.707451007086284),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   28.208971676933597),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.771144129947338),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   25.666901923205195),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.20240084705468),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   24.068063387187806),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   26.006220187500926),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.761908557015367),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   26.757743407389487),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.59058852527233),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   25.055345923934667),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   25.235426100116484),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.62402528871329),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   27.07418090428519),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   26.921195320233007),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   27.102104366086966),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.34868890009516),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.82396325603538),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   24.032011240478692),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   22.607420830531517),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.409262344153515),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   24.769951930536806),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   23.94484751610616),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   26.718991970879948),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   23.126291491543103),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.631489902716282),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   28.13699616479301),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.750292164768435),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   25.521314183601213),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.09820997916443),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   23.979099161839358),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   25.884027175943885),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.652899294527145),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   26.590597704395204),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.4969085591853),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   24.96655813963777),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   25.145523165740897),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.53558371755128),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   26.978424171674583),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   26.827821275095044),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   27.007007897035017),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.27997830776385),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.757784542023675),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   23.964897899585893),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   22.517874143885244),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.322591702154455),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   24.68702842884734),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   23.876120853787295),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   26.571841398740837),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   23.055964789229613),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.555651981133234),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   28.064910244284935),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.728228922935212),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   25.394765945842764),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.007975926859686),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   23.90751734461318),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   25.779741000860856),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.557279584909267),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   26.44485303044487),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.444437282943568),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   24.917431804011166),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   25.095793046491725),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.487485706280737),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   26.923513754881707),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   26.77444406444148),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   26.952506165643733),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.249877495653866),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.729094572799315),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   23.93555599041047),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   22.559455553358262),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.274200318269582),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   24.639030744190205),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   23.838344086355075),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   26.470479558043202),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   23.02450280717842),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.48660724975028),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   28.001754342272722),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.705386304591787),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   25.311188776997614),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   22.95838820732868),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   23.873190275490618),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   25.715572340127384),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.5019960015633),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   26.350352946010304),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU401',
#   'Zone Air Temperature',
#   'C',
#   24.630075466728016),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU402',
#   'Zone Air Temperature',
#   'C',
#   25.094949828372823),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU403',
#   'Zone Air Temperature',
#   'C',
#   25.276013199949613),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N1AU404',
#   'Zone Air Temperature',
#   'C',
#   24.663124042004284),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU101',
#   'Zone Air Temperature',
#   'C',
#   27.123722327140573),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU102',
#   'Zone Air Temperature',
#   'C',
#   26.969360095007914),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU103',
#   'Zone Air Temperature',
#   'C',
#   27.15114131612019),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU201',
#   'Zone Air Temperature',
#   'C',
#   23.382608877685325),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU202',
#   'Zone Air Temperature',
#   'C',
#   23.857937632897247),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU203',
#   'Zone Air Temperature',
#   'C',
#   24.06704583341625),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Air Temperature',
#   'C',
#   22.780197487784523),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2STR',
#   'Zone Air Temperature',
#   'C',
#   24.447396346917444),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBADM',
#   'Zone Air Temperature',
#   'C',
#   24.808720105956215),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Air Temperature',
#   'C',
#   23.983069980140666),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Air Temperature',
#   'C',
#   26.80028758908857),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Air Temperature',
#   'C',
#   23.163607309991402),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Air Temperature',
#   'C',
#   27.665805990950435),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Air Temperature',
#   'C',
#   28.167968082716285),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Air Temperature',
#   'C',
#   25.75934712452447),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBIMP',
#   'Zone Air Temperature',
#   'C',
#   25.587656883445177),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSCOM',
#   'Zone Air Temperature',
#   'C',
#   23.13864915705713),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Air Temperature',
#   'C',
#   24.017746746697256),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Air Temperature',
#   'C',
#   25.938311970002037),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSTR',
#   'Zone Air Temperature',
#   'C',
#   24.695970734269736),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Air Temperature',
#   'C',
#   26.665180698508223),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.42612598871845),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   24.900136229922552),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   25.077893698995528),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.471962150103693),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   26.896416083115753),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   26.748755930441646),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   26.925771259100046),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.248872131339304),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.728049819373805),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   23.933653320206744),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   22.626074544767015),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.257182198872002),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   24.61822066334169),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   23.821011259123257),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   26.39622930745296),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   23.02038862383066),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.423533065081795),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   27.94669497059762),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.68241353397755),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   25.257084504621254),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   22.941374939068),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   23.864767518744763),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   25.678603262586925),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.479080773700268),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   26.289278664181598),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.39880931062078),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   24.872744193696427),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   25.048833722111922),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.446625490008035),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   26.852354919434138),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   26.707144300694353),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   26.882459534310797),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.236975150997573),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.715694727352215),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   23.91949649182327),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   22.588804871196768),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.23191152867817),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   24.589190651313213),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   23.790988775662147),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   26.297528734656638),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   23.00438992647292),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.356322556021055),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   27.886530562629467),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.6596404473763),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   25.18807383389612),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   22.91573057383449),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   23.844207218012425),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   25.626100777229933),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.447343876762826),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   26.202011398263643),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.344972037123306),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   24.819339536712032),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   24.99321699928194),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.39493827548145),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   26.78149347259493),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   26.639215816856964),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   26.81255891477404),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.199249359037104),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.678168548302448),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   23.879816803657736),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   22.468823012826448),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.181595290014556),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   24.537243444581193),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   23.739468422559234),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   26.169570656109283),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   22.96230966866794),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   27.284700058797217),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   27.820630227584676),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.636854699884896),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   25.091094191848967),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   22.86330025811927),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   23.79879796368648),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   25.546675076470727),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   24.389468385235375),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   26.080597430823584),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   24.282647636766676),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   24.758323745968458),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   24.930386632652446),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   24.33522573770868),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   26.708037803528054),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   26.568062081187417),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   26.739884980612093),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   23.15422861711171),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.634029619972452),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   23.834015729040985),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
# ...
#   26.037413118571283),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU102',
#   'Zone Air Temperature',
#   'C',
#   25.914947804517993),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU103',
#   'Zone Air Temperature',
#   'C',
#   26.075785897130412),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU201',
#   'Zone Air Temperature',
#   'C',
#   22.753341145012442),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU202',
#   'Zone Air Temperature',
#   'C',
#   23.24882688632886),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2AU203',
#   'Zone Air Temperature',
#   'C',
#   23.437555615606282),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Air Temperature',
#   'C',
#   21.693218396026),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'N2STR',
#   'Zone Air Temperature',
#   'C',
#   23.55990344350182),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBADM',
#   'Zone Air Temperature',
#   'C',
#   23.893974363031926),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Air Temperature',
#   'C',
#   23.150988174383766),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Air Temperature',
#   'C',
#   24.842253793144206),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Air Temperature',
#   'C',
#   22.449500807224027),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Air Temperature',
#   'C',
#   26.454442721517818),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Air Temperature',
#   'C',
#   27.077242689040123),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Air Temperature',
#   'C',
#   25.321309224475865),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBIMP',
#   'Zone Air Temperature',
#   'C',
#   23.97972014850862),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSCOM',
#   'Zone Air Temperature',
#   'C',
#   22.19179843115853),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Air Temperature',
#   'C',
#   23.269635770103125),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Air Temperature',
#   'C',
#   24.6669553780969),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBSTR',
#   'Zone Air Temperature',
#   'C',
#   23.675706644718527),
#  (2006,
#   1,
#   1,
#   0,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Air Temperature',
#   'C',
#   24.848061368110717),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   23.60240844052046),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   24.10156776370828),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   24.25886542737591),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   23.682954425828544),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   25.908233340770018),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   25.78782450743101),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   25.947759909610433),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   22.695231723381887),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.195053765864017),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   23.382450510645697),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   21.64841270930089),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   23.452916076667005),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.768690548551472),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   23.032059926378334),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   24.568256227310588),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   22.36267523236222),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   26.244635341614543),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   26.898498790801746),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.223880001011587),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   23.743050095085035),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   22.067301591131866),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   23.17928870784288),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   24.49263167093978),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   23.545296490726514),
#  (2006,
#   1,
#   1,
#   10,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   24.619078798233538),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   23.601099794093493),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   24.100190280489763),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   24.256637470413),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   23.68246682469876),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   25.891616966690062),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   25.771863988132864),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   25.931468682632516),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   22.701506887149208),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.2015812690603),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   23.38834302196651),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   21.697922822067806),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   23.448617922015348),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.75692066886286),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   23.013551537257463),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   24.513234301042758),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   22.359311973237006),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   26.187906771173225),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   26.851332532902653),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.196333969537406),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   23.698719637458225),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   22.060214674684705),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   23.174976318763605),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   24.466310665154023),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   23.535476294179535),
#  (2006,
#   1,
#   1,
#   20,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   24.583329296312378),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   23.555136520879433),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   24.055680564648235),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   24.21012296015259),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   23.638072184571932),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   25.828894807190856),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   25.711396156138488),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   25.869573640386733),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   22.66639660959163),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.167851074855072),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   23.353097220795235),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   21.5709457323525),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   23.40372617482245),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.70904915925016),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   22.96190234233839),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   24.403002407926927),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   22.31533334930582),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   26.12021011243117),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   26.790393106525546),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.168712951644874),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   23.607783446099795),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   22.010341284206266),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   23.131882040281486),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   24.396041089303115),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   23.482971569292836),
#  (2006,
#   1,
#   1,
#   30,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   24.48375359492764),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   23.53230743982429),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   24.034228062729834),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   24.187404989484676),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   23.616513933656723),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   25.794676234717098),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   25.67804899828526),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   25.835738871865058),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   22.653954344512687),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.156616152690503),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   23.34110204515289),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   21.611093513891635),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   23.38008034081813),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.680766067061352),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   22.9305181726966),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   24.33222864398788),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   22.294516240799016),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   26.059701302576595),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   26.738121228109),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.1407735048469),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   23.544072138899175),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   21.98248204855886),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   23.111589981179257),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   24.353043430093212),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   23.45260779565621),
#  (2006,
#   1,
#   1,
#   40,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   24.42779647639173),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N1AU401',
#   'Zone Mean Air Temperature',
#   'C',
#   23.54308777484237),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N1AU402',
#   'Zone Mean Air Temperature',
#   'C',
#   24.045336230280757),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N1AU403',
#   'Zone Mean Air Temperature',
#   'C',
#   24.197330690067677),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N1AU404',
#   'Zone Mean Air Temperature',
#   'C',
#   23.628290825724577),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU101',
#   'Zone Mean Air Temperature',
#   'C',
#   25.791980341106722),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU102',
#   'Zone Mean Air Temperature',
#   'C',
#   25.67587008005659),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU103',
#   'Zone Mean Air Temperature',
#   'C',
#   25.833246242111606),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU201',
#   'Zone Mean Air Temperature',
#   'C',
#   22.67307488623011),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU202',
#   'Zone Mean Air Temperature',
#   'C',
#   23.175858452749846),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2AU203',
#   'Zone Mean Air Temperature',
#   'C',
#   23.359655551324472),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2PASILLO',
#   'Zone Mean Air Temperature',
#   'C',
#   21.775891053899933),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'N2STR',
#   'Zone Mean Air Temperature',
#   'C',
#   23.388847509542643),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBADM',
#   'Zone Mean Air Temperature',
#   'C',
#   23.68279626895871),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBATENCIONCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   22.924896127792227),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBCOORCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   24.29971477531389),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBCOORDINACION',
#   'Zone Mean Air Temperature',
#   'C',
#   22.30550713985863),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBDUCTOCOFI',
#   'Zone Mean Air Temperature',
#   'C',
#   26.004163966478426),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBDUCTOSALAS',
#   'Zone Mean Air Temperature',
#   'C',
#   26.6914480204943),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBDUCTOSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   25.112850609445214),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBIMP',
#   'Zone Mean Air Temperature',
#   'C',
#   23.51645421338023),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBSCOM',
#   'Zone Mean Air Temperature',
#   'C',
#   21.990238173113152),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBSJUNTAS',
#   'Zone Mean Air Temperature',
#   'C',
#   23.122080390023044),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBSMAESTROS',
#   'Zone Mean Air Temperature',
#   'C',
#   24.34390597582962),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBSTR',
#   'Zone Mean Air Temperature',
#   'C',
#   23.45599456233203),
#  (2006,
#   1,
#   1,
#   50,
#   'Sunday',
#   'PBVESTIBULO',
#   'Zone Mean Air Temperature',
#   'C',
#   24.41592383575448),
#  ...]

# %%
nombres = ['year','month','day','minute',
           'day_name','value','name','variable','units']

# %%
df = pd.DataFrame(data,columns=nombres)
df.head()
# Out:
#    year  month  day  minute day_name    value                       name  \
# 0  2006      1    1      10   Sunday  N1AU401  Zone Mean Air Temperature
# 1  2006      1    1      10   Sunday  N1AU402  Zone Mean Air Temperature
# 2  2006      1    1      10   Sunday  N1AU403  Zone Mean Air Temperature
# 3  2006      1    1      10   Sunday  N1AU404  Zone Mean Air Temperature
# 4  2006      1    1      10   Sunday  N2AU101  Zone Mean Air Temperature
#
#   variable      units
# 0        C  24.966261
# 1        C  25.425423
# 2        C  25.610684
# 3        C  24.976682
# 4        C  27.549216

# %%
df.loc['name']
